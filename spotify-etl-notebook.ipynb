# %% [markdown]
# ## Spotify - Data - ETL - Pipeline
#
# - In this notebook we will build the ETL pipeline for Spotify data.
# - We will Extract the data from API

# %%
import credentials

# %%
# Import libraries

import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd

# %%
#Connecting to Spotify API and using client id and client secret to authenticate

client_credentials_manager = SpotifyClientCredentials(client_id=credentials.client_id, 
                                                      client_secret=credentials.client_secret)

# %%
sp = spotipy.Spotify(client_credentials_manager = client_credentials_manager)

# %%
playlist_link = "https://open.spotify.com/playlist/37i9dQZEVXbLZ52XmnySJg"

# %%
playlist_URI = playlist_link.split('/')[-1]

# %%
data = sp.playlist_tracks(playlist_URI)

# %%
data['items']
# Out:
# [{'added_at': '2023-06-12T09:44:12Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1mBydYMVBECdDmMfE2sEUO'},
#       'href': 'https://api.spotify.com/v1/artists/1mBydYMVBECdDmMfE2sEUO',
#       'id': '1mBydYMVBECdDmMfE2sEUO',
#       'name': 'Sachin-Jigar',
#       'type': 'artist',
#       'uri': 'spotify:artist:1mBydYMVBECdDmMfE2sEUO'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/4YRxDV8wJFPHPTeXepOstw'},
#       'href': 'https://api.spotify.com/v1/artists/4YRxDV8wJFPHPTeXepOstw',
#       'id': '4YRxDV8wJFPHPTeXepOstw',
#       'name': 'Arijit Singh',
#       'type': 'artist',
#       'uri': 'spotify:artist:4YRxDV8wJFPHPTeXepOstw'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/7uw9rkZ9mxuSBuURy86ERR'},
#       'href': 'https://api.spotify.com/v1/artists/7uw9rkZ9mxuSBuURy86ERR',
#       'id': '7uw9rkZ9mxuSBuURy86ERR',
#       'name': 'Amitabha Bhattacharya',
#       'type': 'artist',
#       'uri': 'spotify:artist:7uw9rkZ9mxuSBuURy86ERR'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'ET',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/1skD49xUwXnHLMrlEKTo6j'},
#     'href': 'https://api.spotify.com/v1/albums/1skD49xUwXnHLMrlEKTo6j',
#     'id': '1skD49xUwXnHLMrlEKTo6j',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2735a5d10c4aaf47bd743df4ed9',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e025a5d10c4aaf47bd743df4ed9',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048515a5d10c4aaf47bd743df4ed9',
#       'width': 64}],
#     'name': 'Phir Aur Kya Chahiye (From "Zara Hatke Zara Bachke") - Single',
#     'release_date': '2023-05-16',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:1skD49xUwXnHLMrlEKTo6j'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1mBydYMVBECdDmMfE2sEUO'},
#      'href': 'https://api.spotify.com/v1/artists/1mBydYMVBECdDmMfE2sEUO',
#      'id': '1mBydYMVBECdDmMfE2sEUO',
#      'name': 'Sachin-Jigar',
#      'type': 'artist',
#      'uri': 'spotify:artist:1mBydYMVBECdDmMfE2sEUO'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/4YRxDV8wJFPHPTeXepOstw'},
#      'href': 'https://api.spotify.com/v1/artists/4YRxDV8wJFPHPTeXepOstw',
#      'id': '4YRxDV8wJFPHPTeXepOstw',
#      'name': 'Arijit Singh',
#      'type': 'artist',
#      'uri': 'spotify:artist:4YRxDV8wJFPHPTeXepOstw'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/7uw9rkZ9mxuSBuURy86ERR'},
#      'href': 'https://api.spotify.com/v1/artists/7uw9rkZ9mxuSBuURy86ERR',
#      'id': '7uw9rkZ9mxuSBuURy86ERR',
#      'name': 'Amitabha Bhattacharya',
#      'type': 'artist',
#      'uri': 'spotify:artist:7uw9rkZ9mxuSBuURy86ERR'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'disc_number': 1,
#    'duration_ms': 266075,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'INH102307527'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/7Ky9U9iHjGBiRax3joCRDS'},
#    'href': 'https://api.spotify.com/v1/tracks/7Ky9U9iHjGBiRax3joCRDS',
#    'id': '7Ky9U9iHjGBiRax3joCRDS',
#    'is_local': False,
#    'name': 'Phir Aur Kya Chahiye (From "Zara Hatke Zara Bachke")',
#    'popularity': 66,
#    'preview_url': 'https://p.scdn.co/mp3-preview/373161ecec289f1201eb298e9d1508db6f581592?cid=7d71303214294d4cbda88e162b0466b1',
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:7Ky9U9iHjGBiRax3joCRDS'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2023-06-12T09:44:12Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1mBydYMVBECdDmMfE2sEUO'},
#       'href': 'https://api.spotify.com/v1/artists/1mBydYMVBECdDmMfE2sEUO',
#       'id': '1mBydYMVBECdDmMfE2sEUO',
#       'name': 'Sachin-Jigar',
#       'type': 'artist',
#       'uri': 'spotify:artist:1mBydYMVBECdDmMfE2sEUO'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/2fMqTqiTxUDlmcOEPaQSsx'},
#       'href': 'https://api.spotify.com/v1/artists/2fMqTqiTxUDlmcOEPaQSsx',
#       'id': '2fMqTqiTxUDlmcOEPaQSsx',
#       'name': 'Amitabh Bhattacharya',
#       'type': 'artist',
#       'uri': 'spotify:artist:2fMqTqiTxUDlmcOEPaQSsx'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'ET',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/6Yb13Od1beXcshjO6vSskt'},
#     'href': 'https://api.spotify.com/v1/albums/6Yb13Od1beXcshjO6vSskt',
#     'id': '6Yb13Od1beXcshjO6vSskt',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27374858a124cf304865a3add86',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0274858a124cf304865a3add86',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485174858a124cf304865a3add86',
#       'width': 64}],
#     'name': 'Zara Hatke Zara Bachke (Original Motion Picture Soundtrack)',
#     'release_date': '2023-05-30',
#     'release_date_precision': 'day',
#     'total_tracks': 4,
#     'type': 'album',
#     'uri': 'spotify:album:6Yb13Od1beXcshjO6vSskt'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4gzrZDyL5gYiROkv27pYKx'},
#      'href': 'https://api.spotify.com/v1/artists/4gzrZDyL5gYiROkv27pYKx',
#      'id': '4gzrZDyL5gYiROkv27pYKx',
#      'name': 'Varun Jain',
#      'type': 'artist',
#      'uri': 'spotify:artist:4gzrZDyL5gYiROkv27pYKx'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/1mBydYMVBECdDmMfE2sEUO'},
#      'href': 'https://api.spotify.com/v1/artists/1mBydYMVBECdDmMfE2sEUO',
#      'id': '1mBydYMVBECdDmMfE2sEUO',
#      'name': 'Sachin-Jigar',
#      'type': 'artist',
#      'uri': 'spotify:artist:1mBydYMVBECdDmMfE2sEUO'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/6WixbETKEXH0xBf0OB9kRB'},
#      'href': 'https://api.spotify.com/v1/artists/6WixbETKEXH0xBf0OB9kRB',
#      'id': '6WixbETKEXH0xBf0OB9kRB',
#      'name': 'Shadab Faridi',
#      'type': 'artist',
#      'uri': 'spotify:artist:6WixbETKEXH0xBf0OB9kRB'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/38IHJBGBuaYXHEkIQd4DtF'},
#      'href': 'https://api.spotify.com/v1/artists/38IHJBGBuaYXHEkIQd4DtF',
#      'id': '38IHJBGBuaYXHEkIQd4DtF',
#      'name': 'Altamash Faridi',
#      'type': 'artist',
#      'uri': 'spotify:artist:38IHJBGBuaYXHEkIQd4DtF'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/2fMqTqiTxUDlmcOEPaQSsx'},
#      'href': 'https://api.spotify.com/v1/artists/2fMqTqiTxUDlmcOEPaQSsx',
#      'id': '2fMqTqiTxUDlmcOEPaQSsx',
#      'name': 'Amitabh Bhattacharya',
#      'type': 'artist',
#      'uri': 'spotify:artist:2fMqTqiTxUDlmcOEPaQSsx'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'disc_number': 1,
#    'duration_ms': 189136,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'INH102307782'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/5GhNEr3AQtMhHGYLRgCSV5'},
#    'href': 'https://api.spotify.com/v1/tracks/5GhNEr3AQtMhHGYLRgCSV5',
#    'id': '5GhNEr3AQtMhHGYLRgCSV5',
#    'is_local': False,
#    'name': 'Tere Vaaste',
#    'popularity': 56,
#    'preview_url': 'https://p.scdn.co/mp3-preview/4520caab8b78238801524b9030816a6112e0ce75?cid=7d71303214294d4cbda88e162b0466b1',
#    'track': True,
#    'track_number': 2,
#    'type': 'track',
#    'uri': 'spotify:track:5GhNEr3AQtMhHGYLRgCSV5'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2023-06-12T09:44:12Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/34gAaWeYZoRER7MY3KBy1Q'},
#       'href': 'https://api.spotify.com/v1/artists/34gAaWeYZoRER7MY3KBy1Q',
#       'id': '34gAaWeYZoRER7MY3KBy1Q',
#       'name': 'Riar Saab',
#       'type': 'artist',
#       'uri': 'spotify:artist:34gAaWeYZoRER7MY3KBy1Q'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/3x1jBMHHrDUQbtRrvV78h2'},
#       'href': 'https://api.spotify.com/v1/artists/3x1jBMHHrDUQbtRrvV78h2',
#       'id': '3x1jBMHHrDUQbtRrvV78h2',
#       'name': 'Abhijay Sharma',
#       'type': 'artist',
#       'uri': 'spotify:artist:3x1jBMHHrDUQbtRrvV78h2'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'ET',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/3LyafXRRJVEfcjTMr1N8Mu'},
#     'href': 'https://api.spotify.com/v1/albums/3LyafXRRJVEfcjTMr1N8Mu',
#     'id': '3LyafXRRJVEfcjTMr1N8Mu',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273a90a3cbabaee190af2f972bf',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02a90a3cbabaee190af2f972bf',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851a90a3cbabaee190af2f972bf',
#       'width': 64}],
#     'name': 'Obsessed',
#     'release_date': '2022-09-29',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:3LyafXRRJVEfcjTMr1N8Mu'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/34gAaWeYZoRER7MY3KBy1Q'},
#      'href': 'https://api.spotify.com/v1/artists/34gAaWeYZoRER7MY3KBy1Q',
#      'id': '34gAaWeYZoRER7MY3KBy1Q',
#      'name': 'Riar Saab',
#      'type': 'artist',
#      'uri': 'spotify:artist:34gAaWeYZoRER7MY3KBy1Q'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/3x1jBMHHrDUQbtRrvV78h2'},
#      'href': 'https://api.spotify.com/v1/artists/3x1jBMHHrDUQbtRrvV78h2',
#      'id': '3x1jBMHHrDUQbtRrvV78h2',
#      'name': 'Abhijay Sharma',
#      'type': 'artist',
#      'uri': 'spotify:artist:3x1jBMHHrDUQbtRrvV78h2'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'disc_number': 1,
#    'duration_ms': 190444,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'QMBZ92299094'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/6Z4rRhYZVQsYKmrxD40tru'},
#    'href': 'https://api.spotify.com/v1/tracks/6Z4rRhYZVQsYKmrxD40tru',
#    'id': '6Z4rRhYZVQsYKmrxD40tru',
#    'is_local': False,
#    'name': 'Obsessed',
#    'popularity': 84,
#    'preview_url': 'https://p.scdn.co/mp3-preview/c746dd0423322ccabefaefe9d04ceb9064ace14e?cid=7d71303214294d4cbda88e162b0466b1',
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:6Z4rRhYZVQsYKmrxD40tru'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2023-06-12T09:44:12Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5r3wPya2PpeTTsXsGhQU8O'},
#       'href': 'https://api.spotify.com/v1/artists/5r3wPya2PpeTTsXsGhQU8O',
#       'id': '5r3wPya2PpeTTsXsGhQU8O',
#       'name': 'Shubh',
#       'type': 'artist',
#       'uri': 'spotify:artist:5r3wPya2PpeTTsXsGhQU8O'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'ET',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/5AivaZj0CiQJoDWqVH2pbh'},
#     'href': 'https://api.spotify.com/v1/albums/5AivaZj0CiQJoDWqVH2pbh',
#     'id': '5AivaZj0CiQJoDWqVH2pbh',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2731a8c4618eda885a406958dd0',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e021a8c4618eda885a406958dd0',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048511a8c4618eda885a406958dd0',
#       'width': 64}],
#     'name': 'Still Rollin',
#     'release_date': '2023-05-19',
#     'release_date_precision': 'day',
#     'total_tracks': 7,
#     'type': 'album',
#     'uri': 'spotify:album:5AivaZj0CiQJoDWqVH2pbh'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5r3wPya2PpeTTsXsGhQU8O'},
#      'href': 'https://api.spotify.com/v1/artists/5r3wPya2PpeTTsXsGhQU8O',
#      'id': '5r3wPya2PpeTTsXsGhQU8O',
#      'name': 'Shubh',
#      'type': 'artist',
#      'uri': 'spotify:artist:5r3wPya2PpeTTsXsGhQU8O'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'disc_number': 1,
#    'duration_ms': 174730,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'QM6P42332209'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/6oz1L5jcqZWYuId7nxvIan'},
#    'href': 'https://api.spotify.com/v1/tracks/6oz1L5jcqZWYuId7nxvIan',
#    'id': '6oz1L5jcqZWYuId7nxvIan',
#    'is_local': False,
#    'name': 'Still Rollin',
#    'popularity': 81,
#    'preview_url': 'https://p.scdn.co/mp3-preview/4b1e40268ac970576e613b89e6d02882658db58d?cid=7d71303214294d4cbda88e162b0466b1',
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:6oz1L5jcqZWYuId7nxvIan'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2023-06-12T09:44:12Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5NHm4TU5Twz7owibYxJfFU'},
#       'href': 'https://api.spotify.com/v1/artists/5NHm4TU5Twz7owibYxJfFU',
#       'id': '5NHm4TU5Twz7owibYxJfFU',
#       'name': 'King',
#       'type': 'artist',
#       'uri': 'spotify:artist:5NHm4TU5Twz7owibYxJfFU'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'ET',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/15CyNDuGY5fsG0Hn9rjnpG'},
#     'href': 'https://api.spotify.com/v1/albums/15CyNDuGY5fsG0Hn9rjnpG',
#     'id': '15CyNDuGY5fsG0Hn9rjnpG',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27337f65266754703fd20d29854',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0237f65266754703fd20d29854',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485137f65266754703fd20d29854',
#       'width': 64}],
#     'name': 'Champagne Talk',
#     'release_date': '2022-10-12',
#     'release_date_precision': 'day',
#     'total_tracks': 8,
#     'type': 'album',
#     'uri': 'spotify:album:15CyNDuGY5fsG0Hn9rjnpG'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5NHm4TU5Twz7owibYxJfFU'},
#      'href': 'https://api.spotify.com/v1/artists/5NHm4TU5Twz7owibYxJfFU',
#      'id': '5NHm4TU5Twz7owibYxJfFU',
#      'name': 'King',
#      'type': 'artist',
#      'uri': 'spotify:artist:5NHm4TU5Twz7owibYxJfFU'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'disc_number': 1,
#    'duration_ms': 194653,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'INW272200083'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/1418IuVKQPTYqt7QNJ9RXN'},
#    'href': 'https://api.spotify.com/v1/tracks/1418IuVKQPTYqt7QNJ9RXN',
#    'id': '1418IuVKQPTYqt7QNJ9RXN',
#    'is_local': False,
#    'name': 'Maan Meri Jaan',
#    'popularity': 86,
#    'preview_url': 'https://p.scdn.co/mp3-preview/cf886ec5f6a46c234bcfdd043ab5db03db0015b4?cid=7d71303214294d4cbda88e162b0466b1',
#    'track': True,
#    'track_number': 4,
#    'type': 'track',
#    'uri': 'spotify:track:1418IuVKQPTYqt7QNJ9RXN'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2023-06-12T09:44:12Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1wRPtKGflJrBx9BmLsSwlU'},
#       'href': 'https://api.spotify.com/v1/artists/1wRPtKGflJrBx9BmLsSwlU',
#       'id': '1wRPtKGflJrBx9BmLsSwlU',
#       'name': 'Pritam',
#       'type': 'artist',
#       'uri': 'spotify:artist:1wRPtKGflJrBx9BmLsSwlU'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/4YRxDV8wJFPHPTeXepOstw'},
#       'href': 'https://api.spotify.com/v1/artists/4YRxDV8wJFPHPTeXepOstw',
#       'id': '4YRxDV8wJFPHPTeXepOstw',
#       'name': 'Arijit Singh',
#       'type': 'artist',
#       'uri': 'spotify:artist:4YRxDV8wJFPHPTeXepOstw'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/2fMqTqiTxUDlmcOEPaQSsx'},
#       'href': 'https://api.spotify.com/v1/artists/2fMqTqiTxUDlmcOEPaQSsx',
#       'id': '2fMqTqiTxUDlmcOEPaQSsx',
#       'name': 'Amitabh Bhattacharya',
#       'type': 'artist',
#       'uri': 'spotify:artist:2fMqTqiTxUDlmcOEPaQSsx'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'ET',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/7kXEDaT5yy8IUT7Fmqs1i2'},
#     'href': 'https://api.spotify.com/v1/albums/7kXEDaT5yy8IUT7Fmqs1i2',
#     'id': '7kXEDaT5yy8IUT7Fmqs1i2',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2732a733a9eeabca1a5fb50312b',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e022a733a9eeabca1a5fb50312b',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048512a733a9eeabca1a5fb50312b',
#       'width': 64}],
#     'name': 'O Bedardeya (From "Tu Jhoothi Main Makkaar")',
#     'release_date': '2023-03-04',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:7kXEDaT5yy8IUT7Fmqs1i2'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1wRPtKGflJrBx9BmLsSwlU'},
#      'href': 'https://api.spotify.com/v1/artists/1wRPtKGflJrBx9BmLsSwlU',
#      'id': '1wRPtKGflJrBx9BmLsSwlU',
#      'name': 'Pritam',
#      'type': 'artist',
#      'uri': 'spotify:artist:1wRPtKGflJrBx9BmLsSwlU'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/4YRxDV8wJFPHPTeXepOstw'},
#      'href': 'https://api.spotify.com/v1/artists/4YRxDV8wJFPHPTeXepOstw',
#      'id': '4YRxDV8wJFPHPTeXepOstw',
#      'name': 'Arijit Singh',
#      'type': 'artist',
#      'uri': 'spotify:artist:4YRxDV8wJFPHPTeXepOstw'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/2fMqTqiTxUDlmcOEPaQSsx'},
#      'href': 'https://api.spotify.com/v1/artists/2fMqTqiTxUDlmcOEPaQSsx',
#      'id': '2fMqTqiTxUDlmcOEPaQSsx',
#      'name': 'Amitabh Bhattacharya',
#      'type': 'artist',
#      'uri': 'spotify:artist:2fMqTqiTxUDlmcOEPaQSsx'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'disc_number': 1,
#    'duration_ms': 313051,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'INS182300550'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/0czcoKJbJt08NqKrvSbbz7'},
#    'href': 'https://api.spotify.com/v1/tracks/0czcoKJbJt08NqKrvSbbz7',
#    'id': '0czcoKJbJt08NqKrvSbbz7',
#    'is_local': False,
#    'name': 'O Bedardeya (From "Tu Jhoothi Main Makkaar")',
#    'popularity': 86,
#    'preview_url': 'https://p.scdn.co/mp3-preview/63f3c9be6a7b68ba1ec33baa701140d6b4837aca?cid=7d71303214294d4cbda88e162b0466b1',
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:0czcoKJbJt08NqKrvSbbz7'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2023-06-12T09:44:12Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6WOdPJmexxFINcKMkP2jMG'},
#       'href': 'https://api.spotify.com/v1/artists/6WOdPJmexxFINcKMkP2jMG',
#       'id': '6WOdPJmexxFINcKMkP2jMG',
#       'name': 'Sachet Tandon',
#       'type': 'artist',
#       'uri': 'spotify:artist:6WOdPJmexxFINcKMkP2jMG'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/1E6arsXf5Fgsnv9YpSzjpE'},
#       'href': 'https://api.spotify.com/v1/artists/1E6arsXf5Fgsnv9YpSzjpE',
#       'id': '1E6arsXf5Fgsnv9YpSzjpE',
#       'name': 'Parampara Tandon',
#       'type': 'artist',
#       'uri': 'spotify:artist:1E6arsXf5Fgsnv9YpSzjpE'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/0m3D4grap8VFSzbJMqgNVk'},
#       'href': 'https://api.spotify.com/v1/artists/0m3D4grap8VFSzbJMqgNVk',
#       'id': '0m3D4grap8VFSzbJMqgNVk',
#       'name': 'Kumaar',
#       'type': 'artist',
#       'uri': 'spotify:artist:0m3D4grap8VFSzbJMqgNVk'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'ET',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/7khRLZe8P6XcUoRgOa3nnf'},
#     'href': 'https://api.spotify.com/v1/albums/7khRLZe8P6XcUoRgOa3nnf',
#     'id': '7khRLZe8P6XcUoRgOa3nnf',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273e4be675de3a03b2ad2552c6d',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02e4be675de3a03b2ad2552c6d',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851e4be675de3a03b2ad2552c6d',
#       'width': 64}],
#     'name': 'Malang Sajna',
#     'release_date': '2022-12-19',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:7khRLZe8P6XcUoRgOa3nnf'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6WOdPJmexxFINcKMkP2jMG'},
#      'href': 'https://api.spotify.com/v1/artists/6WOdPJmexxFINcKMkP2jMG',
#      'id': '6WOdPJmexxFINcKMkP2jMG',
#      'name': 'Sachet Tandon',
#      'type': 'artist',
#      'uri': 'spotify:artist:6WOdPJmexxFINcKMkP2jMG'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/1E6arsXf5Fgsnv9YpSzjpE'},
#      'href': 'https://api.spotify.com/v1/artists/1E6arsXf5Fgsnv9YpSzjpE',
#      'id': '1E6arsXf5Fgsnv9YpSzjpE',
#      'name': 'Parampara Tandon',
#      'type': 'artist',
#      'uri': 'spotify:artist:1E6arsXf5Fgsnv9YpSzjpE'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/0m3D4grap8VFSzbJMqgNVk'},
#      'href': 'https://api.spotify.com/v1/artists/0m3D4grap8VFSzbJMqgNVk',
#      'id': '0m3D4grap8VFSzbJMqgNVk',
#      'name': 'Kumaar',
#      'type': 'artist',
#      'uri': 'spotify:artist:0m3D4grap8VFSzbJMqgNVk'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/1SyKki7JI1AZNKwgNMkn25'},
#      'href': 'https://api.spotify.com/v1/artists/1SyKki7JI1AZNKwgNMkn25',
# ...
#      'href': 'https://api.spotify.com/v1/artists/2fMqTqiTxUDlmcOEPaQSsx',
#      'id': '2fMqTqiTxUDlmcOEPaQSsx',
#      'name': 'Amitabh Bhattacharya',
#      'type': 'artist',
#      'uri': 'spotify:artist:2fMqTqiTxUDlmcOEPaQSsx'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/00sCATpEvwH48ays7PlQFU'},
#      'href': 'https://api.spotify.com/v1/artists/00sCATpEvwH48ays7PlQFU',
#      'id': '00sCATpEvwH48ays7PlQFU',
#      'name': 'Jonita Gandhi',
#      'type': 'artist',
#      'uri': 'spotify:artist:00sCATpEvwH48ays7PlQFU'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'disc_number': 1,
#    'duration_ms': 279107,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'INS172219983'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/4SqPZorSDuUtvdJwVGeZRC'},
#    'href': 'https://api.spotify.com/v1/tracks/4SqPZorSDuUtvdJwVGeZRC',
#    'id': '4SqPZorSDuUtvdJwVGeZRC',
#    'is_local': False,
#    'name': 'Deva Deva',
#    'popularity': 68,
#    'preview_url': 'https://p.scdn.co/mp3-preview/0238ffb0511435c15e33b3306f38ed6992ced6d1?cid=7d71303214294d4cbda88e162b0466b1',
#    'track': True,
#    'track_number': 2,
#    'type': 'track',
#    'uri': 'spotify:track:4SqPZorSDuUtvdJwVGeZRC'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2023-06-12T09:44:12Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1Xyo4u8uXC1ZmMpatF05PJ'},
#       'href': 'https://api.spotify.com/v1/artists/1Xyo4u8uXC1ZmMpatF05PJ',
#       'id': '1Xyo4u8uXC1ZmMpatF05PJ',
#       'name': 'The Weeknd',
#       'type': 'artist',
#       'uri': 'spotify:artist:1Xyo4u8uXC1ZmMpatF05PJ'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'ET',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/2ODvWsOgouMbaA5xf0RkJe'},
#     'href': 'https://api.spotify.com/v1/albums/2ODvWsOgouMbaA5xf0RkJe',
#     'id': '2ODvWsOgouMbaA5xf0RkJe',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2734718e2b124f79258be7bc452',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e024718e2b124f79258be7bc452',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048514718e2b124f79258be7bc452',
#       'width': 64}],
#     'name': 'Starboy',
#     'release_date': '2016-11-25',
#     'release_date_precision': 'day',
#     'total_tracks': 18,
#     'type': 'album',
#     'uri': 'spotify:album:2ODvWsOgouMbaA5xf0RkJe'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1Xyo4u8uXC1ZmMpatF05PJ'},
#      'href': 'https://api.spotify.com/v1/artists/1Xyo4u8uXC1ZmMpatF05PJ',
#      'id': '1Xyo4u8uXC1ZmMpatF05PJ',
#      'name': 'The Weeknd',
#      'type': 'artist',
#      'uri': 'spotify:artist:1Xyo4u8uXC1ZmMpatF05PJ'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/4tZwfgrHOc3mvqYlEYSvVi'},
#      'href': 'https://api.spotify.com/v1/artists/4tZwfgrHOc3mvqYlEYSvVi',
#      'id': '4tZwfgrHOc3mvqYlEYSvVi',
#      'name': 'Daft Punk',
#      'type': 'artist',
#      'uri': 'spotify:artist:4tZwfgrHOc3mvqYlEYSvVi'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'disc_number': 1,
#    'duration_ms': 230453,
#    'episode': False,
#    'explicit': True,
#    'external_ids': {'isrc': 'USUG11600976'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/7MXVkk9YMctZqd1Srtv4MB'},
#    'href': 'https://api.spotify.com/v1/tracks/7MXVkk9YMctZqd1Srtv4MB',
#    'id': '7MXVkk9YMctZqd1Srtv4MB',
#    'is_local': False,
#    'name': 'Starboy',
#    'popularity': 93,
#    'preview_url': None,
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:7MXVkk9YMctZqd1Srtv4MB'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2023-06-12T09:44:12Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4YRxDV8wJFPHPTeXepOstw'},
#       'href': 'https://api.spotify.com/v1/artists/4YRxDV8wJFPHPTeXepOstw',
#       'id': '4YRxDV8wJFPHPTeXepOstw',
#       'name': 'Arijit Singh',
#       'type': 'artist',
#       'uri': 'spotify:artist:4YRxDV8wJFPHPTeXepOstw'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'ET',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/1WwkojG9sjMSrFVz4D51W0'},
#     'href': 'https://api.spotify.com/v1/albums/1WwkojG9sjMSrFVz4D51W0',
#     'id': '1WwkojG9sjMSrFVz4D51W0',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2731aa5adad8593923dcdf1a7d0',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e021aa5adad8593923dcdf1a7d0',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048511aa5adad8593923dcdf1a7d0',
#       'width': 64}],
#     'name': 'Ultimate Love Songs - Arijit Singh',
#     'release_date': '2020-05-19',
#     'release_date_precision': 'day',
#     'total_tracks': 10,
#     'type': 'album',
#     'uri': 'spotify:album:1WwkojG9sjMSrFVz4D51W0'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4YRxDV8wJFPHPTeXepOstw'},
#      'href': 'https://api.spotify.com/v1/artists/4YRxDV8wJFPHPTeXepOstw',
#      'id': '4YRxDV8wJFPHPTeXepOstw',
#      'name': 'Arijit Singh',
#      'type': 'artist',
#      'uri': 'spotify:artist:4YRxDV8wJFPHPTeXepOstw'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'disc_number': 1,
#    'duration_ms': 260590,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'INS181401039'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/2PvaburAUlhNHxVhw5lvOq'},
#    'href': 'https://api.spotify.com/v1/tracks/2PvaburAUlhNHxVhw5lvOq',
#    'id': '2PvaburAUlhNHxVhw5lvOq',
#    'is_local': False,
#    'name': 'Humdard (From "Ek Villain")',
#    'popularity': 74,
#    'preview_url': 'https://p.scdn.co/mp3-preview/4b5f53af2131c4af06009ef1b204c748fa4e77cb?cid=7d71303214294d4cbda88e162b0466b1',
#    'track': True,
#    'track_number': 6,
#    'type': 'track',
#    'uri': 'spotify:track:2PvaburAUlhNHxVhw5lvOq'},
#   'video_thumbnail': {'url': None}}]

# %%
data['items'][0]['track']['album']['id']
# Out:
# '1skD49xUwXnHLMrlEKTo6j'

# %%
data['items'][0]['track']['album']['name']
# Out:
# 'Phir Aur Kya Chahiye (From "Zara Hatke Zara Bachke") - Single'

# %%
data['items'][0]['track']['album']['release_date']
# Out:
# '2023-05-16'

# %%
data['items'][0]['track']['album']['total_tracks']
# Out:
# 1

# %%
data['items'][0]['track']['album']['external_urls']['spotify']
# Out:
# 'https://open.spotify.com/album/1skD49xUwXnHLMrlEKTo6j'

# %%
album_list = []
for row in data['items']:
    album_id = row['track']['album']['id']
    album_name = row['track']['album']['name']
    album_release_date = row['track']['album']['release_date']
    album_total_tracks = row['track']['album']['total_tracks']
    album_url = row['track']['album']['external_urls']['spotify']
    album_element = {'album_id':album_id,'name':album_name,'release_date':album_release_date,
                     'total_tracks':album_total_tracks,'url':album_url}
    album_list.append(album_element)

# %%
album_list
# Out:
# [{'album_id': '1skD49xUwXnHLMrlEKTo6j',
#   'name': 'Phir Aur Kya Chahiye (From "Zara Hatke Zara Bachke") - Single',
#   'release_date': '2023-05-16',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/1skD49xUwXnHLMrlEKTo6j'},
#  {'album_id': '6Yb13Od1beXcshjO6vSskt',
#   'name': 'Zara Hatke Zara Bachke (Original Motion Picture Soundtrack)',
#   'release_date': '2023-05-30',
#   'total_tracks': 4,
#   'url': 'https://open.spotify.com/album/6Yb13Od1beXcshjO6vSskt'},
#  {'album_id': '3LyafXRRJVEfcjTMr1N8Mu',
#   'name': 'Obsessed',
#   'release_date': '2022-09-29',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/3LyafXRRJVEfcjTMr1N8Mu'},
#  {'album_id': '5AivaZj0CiQJoDWqVH2pbh',
#   'name': 'Still Rollin',
#   'release_date': '2023-05-19',
#   'total_tracks': 7,
#   'url': 'https://open.spotify.com/album/5AivaZj0CiQJoDWqVH2pbh'},
#  {'album_id': '15CyNDuGY5fsG0Hn9rjnpG',
#   'name': 'Champagne Talk',
#   'release_date': '2022-10-12',
#   'total_tracks': 8,
#   'url': 'https://open.spotify.com/album/15CyNDuGY5fsG0Hn9rjnpG'},
#  {'album_id': '7kXEDaT5yy8IUT7Fmqs1i2',
#   'name': 'O Bedardeya (From "Tu Jhoothi Main Makkaar")',
#   'release_date': '2023-03-04',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/7kXEDaT5yy8IUT7Fmqs1i2'},
#  {'album_id': '7khRLZe8P6XcUoRgOa3nnf',
#   'name': 'Malang Sajna',
#   'release_date': '2022-12-19',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/7khRLZe8P6XcUoRgOa3nnf'},
#  {'album_id': '4kIPlpwEZBK9JaI9pZHe79',
#   'name': 'Brahmastra (Original Motion Picture Soundtrack)',
#   'release_date': '2022-10-06',
#   'total_tracks': 9,
#   'url': 'https://open.spotify.com/album/4kIPlpwEZBK9JaI9pZHe79'},
#  {'album_id': '54ubCIO3voLnU7ZmJhxqBd',
#   'name': 'Zihaal e Miskin',
#   'release_date': '2023-05-25',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/54ubCIO3voLnU7ZmJhxqBd'},
#  {'album_id': '6BHlJhCk1vjCG6hqTG2SFV',
#   'name': 'Kahani Suno 2.0',
#   'release_date': '2022-05-31',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/6BHlJhCk1vjCG6hqTG2SFV'},
#  {'album_id': '25OmZbss1JS6CdFqFDiaNu',
#   'name': 'Ram Siya Ram (From "Adipurush")',
#   'release_date': '2023-05-29',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/25OmZbss1JS6CdFqFDiaNu'},
#  {'album_id': '5Wm1nhxZqx7i0Hp6ZBqe9T',
#   'name': 'Love Forever With Arijit Singh',
#   'release_date': '2017-06-07',
#   'total_tracks': 20,
#   'url': 'https://open.spotify.com/album/5Wm1nhxZqx7i0Hp6ZBqe9T'},
#  {'album_id': '5AivaZj0CiQJoDWqVH2pbh',
#   'name': 'Still Rollin',
#   'release_date': '2023-05-19',
#   'total_tracks': 7,
#   'url': 'https://open.spotify.com/album/5AivaZj0CiQJoDWqVH2pbh'},
#  {'album_id': '5uAi4ZZc7zRdd6PsKNcJXO',
#   'name': 'Tere Pyaar Mein (From "Tu Jhoothi Main Makkaar")',
#   'release_date': '2023-02-01',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/5uAi4ZZc7zRdd6PsKNcJXO'},
#  {'album_id': '1lZk7TnMgvS3mSlfeWW1b3',
#   'name': 'Tere Hawaale (From "Laal Singh Chaddha")',
#   'release_date': '2022-08-04',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/1lZk7TnMgvS3mSlfeWW1b3'},
#  {'album_id': '5Zcgog7sQ79ISF32y9nABU',
#   'name': 'No Love',
#   'release_date': '2022-02-22',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/5Zcgog7sQ79ISF32y9nABU'},
#  {'album_id': '76spwPLkGkvPtADGCTkNeT',
#   'name': 'Kya Loge Tum',
#   'release_date': '2023-05-15',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/76spwPLkGkvPtADGCTkNeT'},
#  {'album_id': '3RaIXDlIRvziryGLXm8lBR',
#   'name': 'Daku',
#   'release_date': '2021-01-16',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/3RaIXDlIRvziryGLXm8lBR'},
#  {'album_id': '2ooWY7xriwwyj23dAI32C2',
#   'name': 'Pathaan',
#   'release_date': '2022-12-22',
#   'total_tracks': 4,
#   'url': 'https://open.spotify.com/album/2ooWY7xriwwyj23dAI32C2'},
#  {'album_id': '7uftfPn8f7lwtRLUrEVRYM',
#   'name': 'The Carnival',
#   'release_date': '2020-09-21',
#   'total_tracks': 8,
#   'url': 'https://open.spotify.com/album/7uftfPn8f7lwtRLUrEVRYM'},
#  {'album_id': '6AJaDEafyyyWWXHZQtcFGe',
#   'name': 'Chaand Baaliyan',
#   'release_date': '2020-03-28',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/6AJaDEafyyyWWXHZQtcFGe'},
#  {'album_id': '44aCFqUbG06fL58kqpMp8p',
#   'name': 'Baller',
#   'release_date': '2022-09-09',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/44aCFqUbG06fL58kqpMp8p'},
#  {'album_id': '1cttjZoENYipDCPgISthpY',
#   'name': 'Pyaar Hota Kayi Baar Hai (From "Tu Jhoothi Main Makkaar")',
#   'release_date': '2023-02-10',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/1cttjZoENYipDCPgISthpY'},
#  {'album_id': '4qlI6YM61j9NeGe832mExq',
#   'name': 'Forever',
#   'release_date': '2022-11-16',
#   'total_tracks': 6,
#   'url': 'https://open.spotify.com/album/4qlI6YM61j9NeGe832mExq'},
#  {'album_id': '2DKSZvMj7Da6rzNVPMgREj',
#   'name': 'Raataan Lambiyan (From "Shershaah")',
#   'release_date': '2021-07-30',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/2DKSZvMj7Da6rzNVPMgREj'},
#  {'album_id': '45ZIondgVoMB84MQQaUo9T',
#   'name': 'Moosetape',
#   'release_date': '2021-05-15',
#   'total_tracks': 32,
#   'url': 'https://open.spotify.com/album/45ZIondgVoMB84MQQaUo9T'},
#  {'album_id': '3I8PdIhk6pNm8Kv0HiF14V',
#   'name': 'Tujhe Kitna Chahne Lage (From "Kabir Singh")',
#   'release_date': '2019-05-31',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/3I8PdIhk6pNm8Kv0HiF14V'},
#  {'album_id': '6KgPhunJItRDOhJFh6Sy78',
#   'name': 'Drive Thru',
#   'release_date': '2022-07-15',
#   'total_tracks': 5,
#   'url': 'https://open.spotify.com/album/6KgPhunJItRDOhJFh6Sy78'},
#  {'album_id': '3fOswFPlmSWKTTFTlksdiv',
#   'name': 'HIDDEN GEMS',
#   'release_date': '2021-11-21',
#   'total_tracks': 6,
#   'url': 'https://open.spotify.com/album/3fOswFPlmSWKTTFTlksdiv'},
#  {'album_id': '0azGrKHPYvl2MEKwQFfbV2',
#   'name': 'Mi Amor',
#   'release_date': '2022-09-30',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/0azGrKHPYvl2MEKwQFfbV2'},
#  {'album_id': '6u5RdRVp5HBStyPRWvHcgm',
#   'name': 'Thaa',
#   'release_date': '2023-03-25',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/6u5RdRVp5HBStyPRWvHcgm'},
#  {'album_id': '3GkXRRRkV3rfgwG1wJset9',
#   'name': 'Excuses',
#   'release_date': '2020-07-24',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/3GkXRRRkV3rfgwG1wJset9'},
#  {'album_id': '2GPHbR6aZ2rZooX6dF1nwB',
#   'name': 'VIBIN',
#   'release_date': '2023-01-09',
#   'total_tracks': 7,
#   'url': 'https://open.spotify.com/album/2GPHbR6aZ2rZooX6dF1nwB'},
#  {'album_id': '5CvI5ppsG522pV554VLezD',
#   'name': 'Besharam Rang (From "Pathaan")',
#   'release_date': '2022-12-12',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/5CvI5ppsG522pV554VLezD'},
#  {'album_id': '4ysOhipyMXKstywus51VXS',
#   'name': 'Baarishein',
#   'release_date': '2018-01-12',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/4ysOhipyMXKstywus51VXS'},
#  {'album_id': '4QCM8VlhhlwZtQ2Ew7gtIg',
#   'name': 'Pal',
#   'release_date': '2018-09-14',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/4QCM8VlhhlwZtQ2Ew7gtIg'},
#  {'album_id': '0Z1zYMwJRpvq0d9rdqTOYo',
#   'name': 'Ranjha (From "Shershaah")',
#   'release_date': '2021-08-05',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/0Z1zYMwJRpvq0d9rdqTOYo'},
#  {'album_id': '1N9rGbn2M9lzU6YcJ6081E',
#   'name': 'Manjha',
#   'release_date': '2020-03-17',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/1N9rGbn2M9lzU6YcJ6081E'},
#  {'album_id': '6IXfWhC7omotM4lt0ROmEr',
#   'name': 'Love Aaj Kal (Original Motion Picture Soundtrack)',
#   'release_date': '2020-02-14',
#   'total_tracks': 11,
#   'url': 'https://open.spotify.com/album/6IXfWhC7omotM4lt0ROmEr'},
#  {'album_id': '5letLUZIFsQikJYShfGNs4',
#   'name': 'The Beginning: Cupid',
#   'release_date': '2023-02-24',
#   'total_tracks': 3,
#   'url': 'https://open.spotify.com/album/5letLUZIFsQikJYShfGNs4'},
#  {'album_id': '7Gws1vUsWltRs58x8QuYVQ',
#   'name': 'Table No. 21 (Original Motion Picture Soundtrack)',
#   'release_date': '2012-12-21',
#   'total_tracks': 5,
#   'url': 'https://open.spotify.com/album/7Gws1vUsWltRs58x8QuYVQ'},
#  {'album_id': '5hzAIEMlQpsEGIQFvnFOQx',
#   'name': 'Duniyaa (From "Luka Chuppi")',
#   'release_date': '2019-02-22',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/5hzAIEMlQpsEGIQFvnFOQx'},
#  {'album_id': '1ncyKqyZae6DoyjYaV9LmS',
#   'name': 'Kaise Hua (From "Kabir Singh")',
#   'release_date': '2019-06-13',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/1ncyKqyZae6DoyjYaV9LmS'},
#  {'album_id': '5Hmh6N8oisrcuZKa8EY5dn',
#   'name': 'People',
#   'release_date': '2022-12-06',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/5Hmh6N8oisrcuZKa8EY5dn'},
#  {'album_id': '2HZl13JCi3PIaqVlIkp4q6',
#   'name': 'Shor in the City (Original Motion Picture Soundtrack)',
#   'release_date': '2011-03-28',
#   'total_tracks': 8,
#   'url': 'https://open.spotify.com/album/2HZl13JCi3PIaqVlIkp4q6'},
#  {'album_id': '3jeQDa9OFZ6GndLindHx3k',
#   'name': 'Take Two',
#   'release_date': '2023-06-09',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/3jeQDa9OFZ6GndLindHx3k'},
#  {'album_id': '64MZHXV7IglO8LE8KplSRw',
#   'name': 'ANYWAY',
#   'release_date': '2023-01-30',
#   'total_tracks': 10,
#   'url': 'https://open.spotify.com/album/64MZHXV7IglO8LE8KplSRw'},
#  {'album_id': '4kIPlpwEZBK9JaI9pZHe79',
#   'name': 'Brahmastra (Original Motion Picture Soundtrack)',
#   'release_date': '2022-10-06',
#   'total_tracks': 9,
#   'url': 'https://open.spotify.com/album/4kIPlpwEZBK9JaI9pZHe79'},
#  {'album_id': '2ODvWsOgouMbaA5xf0RkJe',
#   'name': 'Starboy',
#   'release_date': '2016-11-25',
#   'total_tracks': 18,
#   'url': 'https://open.spotify.com/album/2ODvWsOgouMbaA5xf0RkJe'},
#  {'album_id': '1WwkojG9sjMSrFVz4D51W0',
#   'name': 'Ultimate Love Songs - Arijit Singh',
#   'release_date': '2020-05-19',
#   'total_tracks': 10,
#   'url': 'https://open.spotify.com/album/1WwkojG9sjMSrFVz4D51W0'}]

# %%
data['items'][0]
# Out:
# {'added_at': '2023-06-12T09:44:12Z',
#  'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#   'href': 'https://api.spotify.com/v1/users/',
#   'id': '',
#   'type': 'user',
#   'uri': 'spotify:user:'},
#  'is_local': False,
#  'primary_color': None,
#  'track': {'album': {'album_type': 'single',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1mBydYMVBECdDmMfE2sEUO'},
#      'href': 'https://api.spotify.com/v1/artists/1mBydYMVBECdDmMfE2sEUO',
#      'id': '1mBydYMVBECdDmMfE2sEUO',
#      'name': 'Sachin-Jigar',
#      'type': 'artist',
#      'uri': 'spotify:artist:1mBydYMVBECdDmMfE2sEUO'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/4YRxDV8wJFPHPTeXepOstw'},
#      'href': 'https://api.spotify.com/v1/artists/4YRxDV8wJFPHPTeXepOstw',
#      'id': '4YRxDV8wJFPHPTeXepOstw',
#      'name': 'Arijit Singh',
#      'type': 'artist',
#      'uri': 'spotify:artist:4YRxDV8wJFPHPTeXepOstw'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/7uw9rkZ9mxuSBuURy86ERR'},
#      'href': 'https://api.spotify.com/v1/artists/7uw9rkZ9mxuSBuURy86ERR',
#      'id': '7uw9rkZ9mxuSBuURy86ERR',
#      'name': 'Amitabha Bhattacharya',
#      'type': 'artist',
#      'uri': 'spotify:artist:7uw9rkZ9mxuSBuURy86ERR'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CD',
#     'CG',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'ET',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IQ',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'LY',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TJ',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VE',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/1skD49xUwXnHLMrlEKTo6j'},
#    'href': 'https://api.spotify.com/v1/albums/1skD49xUwXnHLMrlEKTo6j',
#    'id': '1skD49xUwXnHLMrlEKTo6j',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2735a5d10c4aaf47bd743df4ed9',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e025a5d10c4aaf47bd743df4ed9',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048515a5d10c4aaf47bd743df4ed9',
#      'width': 64}],
#    'name': 'Phir Aur Kya Chahiye (From "Zara Hatke Zara Bachke") - Single',
#    'release_date': '2023-05-16',
#    'release_date_precision': 'day',
#    'total_tracks': 1,
#    'type': 'album',
#    'uri': 'spotify:album:1skD49xUwXnHLMrlEKTo6j'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1mBydYMVBECdDmMfE2sEUO'},
#     'href': 'https://api.spotify.com/v1/artists/1mBydYMVBECdDmMfE2sEUO',
#     'id': '1mBydYMVBECdDmMfE2sEUO',
#     'name': 'Sachin-Jigar',
#     'type': 'artist',
#     'uri': 'spotify:artist:1mBydYMVBECdDmMfE2sEUO'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/4YRxDV8wJFPHPTeXepOstw'},
#     'href': 'https://api.spotify.com/v1/artists/4YRxDV8wJFPHPTeXepOstw',
#     'id': '4YRxDV8wJFPHPTeXepOstw',
#     'name': 'Arijit Singh',
#     'type': 'artist',
#     'uri': 'spotify:artist:4YRxDV8wJFPHPTeXepOstw'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/7uw9rkZ9mxuSBuURy86ERR'},
#     'href': 'https://api.spotify.com/v1/artists/7uw9rkZ9mxuSBuURy86ERR',
#     'id': '7uw9rkZ9mxuSBuURy86ERR',
#     'name': 'Amitabha Bhattacharya',
#     'type': 'artist',
#     'uri': 'spotify:artist:7uw9rkZ9mxuSBuURy86ERR'}],
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'BY',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XK'],
#   'disc_number': 1,
#   'duration_ms': 266075,
#   'episode': False,
#   'explicit': False,
#   'external_ids': {'isrc': 'INH102307527'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/7Ky9U9iHjGBiRax3joCRDS'},
#   'href': 'https://api.spotify.com/v1/tracks/7Ky9U9iHjGBiRax3joCRDS',
#   'id': '7Ky9U9iHjGBiRax3joCRDS',
#   'is_local': False,
#   'name': 'Phir Aur Kya Chahiye (From "Zara Hatke Zara Bachke")',
#   'popularity': 66,
#   'preview_url': 'https://p.scdn.co/mp3-preview/373161ecec289f1201eb298e9d1508db6f581592?cid=7d71303214294d4cbda88e162b0466b1',
#   'track': True,
#   'track_number': 1,
#   'type': 'track',
#   'uri': 'spotify:track:7Ky9U9iHjGBiRax3joCRDS'},
#  'video_thumbnail': {'url': None}}

# %%
artist_list = []
for row in data['items']:
    for key, value in row.items():
        if key == "track":
            for artist in value['artists']:
                artist_dict = {'artist_id':artist['id'], 'artist_name':artist['name'], 'external_url': artist['href']}
                artist_list.append(artist_dict)

# %%
artist_list
# Out:
# [{'artist_id': '1mBydYMVBECdDmMfE2sEUO',
#   'artist_name': 'Sachin-Jigar',
#   'external_url': 'https://api.spotify.com/v1/artists/1mBydYMVBECdDmMfE2sEUO'},
#  {'artist_id': '4YRxDV8wJFPHPTeXepOstw',
#   'artist_name': 'Arijit Singh',
#   'external_url': 'https://api.spotify.com/v1/artists/4YRxDV8wJFPHPTeXepOstw'},
#  {'artist_id': '7uw9rkZ9mxuSBuURy86ERR',
#   'artist_name': 'Amitabha Bhattacharya',
#   'external_url': 'https://api.spotify.com/v1/artists/7uw9rkZ9mxuSBuURy86ERR'},
#  {'artist_id': '4gzrZDyL5gYiROkv27pYKx',
#   'artist_name': 'Varun Jain',
#   'external_url': 'https://api.spotify.com/v1/artists/4gzrZDyL5gYiROkv27pYKx'},
#  {'artist_id': '1mBydYMVBECdDmMfE2sEUO',
#   'artist_name': 'Sachin-Jigar',
#   'external_url': 'https://api.spotify.com/v1/artists/1mBydYMVBECdDmMfE2sEUO'},
#  {'artist_id': '6WixbETKEXH0xBf0OB9kRB',
#   'artist_name': 'Shadab Faridi',
#   'external_url': 'https://api.spotify.com/v1/artists/6WixbETKEXH0xBf0OB9kRB'},
#  {'artist_id': '38IHJBGBuaYXHEkIQd4DtF',
#   'artist_name': 'Altamash Faridi',
#   'external_url': 'https://api.spotify.com/v1/artists/38IHJBGBuaYXHEkIQd4DtF'},
#  {'artist_id': '2fMqTqiTxUDlmcOEPaQSsx',
#   'artist_name': 'Amitabh Bhattacharya',
#   'external_url': 'https://api.spotify.com/v1/artists/2fMqTqiTxUDlmcOEPaQSsx'},
#  {'artist_id': '34gAaWeYZoRER7MY3KBy1Q',
#   'artist_name': 'Riar Saab',
#   'external_url': 'https://api.spotify.com/v1/artists/34gAaWeYZoRER7MY3KBy1Q'},
#  {'artist_id': '3x1jBMHHrDUQbtRrvV78h2',
#   'artist_name': 'Abhijay Sharma',
#   'external_url': 'https://api.spotify.com/v1/artists/3x1jBMHHrDUQbtRrvV78h2'},
#  {'artist_id': '5r3wPya2PpeTTsXsGhQU8O',
#   'artist_name': 'Shubh',
#   'external_url': 'https://api.spotify.com/v1/artists/5r3wPya2PpeTTsXsGhQU8O'},
#  {'artist_id': '5NHm4TU5Twz7owibYxJfFU',
#   'artist_name': 'King',
#   'external_url': 'https://api.spotify.com/v1/artists/5NHm4TU5Twz7owibYxJfFU'},
#  {'artist_id': '1wRPtKGflJrBx9BmLsSwlU',
#   'artist_name': 'Pritam',
#   'external_url': 'https://api.spotify.com/v1/artists/1wRPtKGflJrBx9BmLsSwlU'},
#  {'artist_id': '4YRxDV8wJFPHPTeXepOstw',
#   'artist_name': 'Arijit Singh',
#   'external_url': 'https://api.spotify.com/v1/artists/4YRxDV8wJFPHPTeXepOstw'},
#  {'artist_id': '2fMqTqiTxUDlmcOEPaQSsx',
#   'artist_name': 'Amitabh Bhattacharya',
#   'external_url': 'https://api.spotify.com/v1/artists/2fMqTqiTxUDlmcOEPaQSsx'},
#  {'artist_id': '6WOdPJmexxFINcKMkP2jMG',
#   'artist_name': 'Sachet Tandon',
#   'external_url': 'https://api.spotify.com/v1/artists/6WOdPJmexxFINcKMkP2jMG'},
#  {'artist_id': '1E6arsXf5Fgsnv9YpSzjpE',
#   'artist_name': 'Parampara Tandon',
#   'external_url': 'https://api.spotify.com/v1/artists/1E6arsXf5Fgsnv9YpSzjpE'},
#  {'artist_id': '0m3D4grap8VFSzbJMqgNVk',
#   'artist_name': 'Kumaar',
#   'external_url': 'https://api.spotify.com/v1/artists/0m3D4grap8VFSzbJMqgNVk'},
#  {'artist_id': '1SyKki7JI1AZNKwgNMkn25',
#   'artist_name': 'Sachet-Parampara',
#   'external_url': 'https://api.spotify.com/v1/artists/1SyKki7JI1AZNKwgNMkn25'},
#  {'artist_id': '1wRPtKGflJrBx9BmLsSwlU',
#   'artist_name': 'Pritam',
#   'external_url': 'https://api.spotify.com/v1/artists/1wRPtKGflJrBx9BmLsSwlU'},
#  {'artist_id': '4YRxDV8wJFPHPTeXepOstw',
#   'artist_name': 'Arijit Singh',
#   'external_url': 'https://api.spotify.com/v1/artists/4YRxDV8wJFPHPTeXepOstw'},
#  {'artist_id': '2fMqTqiTxUDlmcOEPaQSsx',
#   'artist_name': 'Amitabh Bhattacharya',
#   'external_url': 'https://api.spotify.com/v1/artists/2fMqTqiTxUDlmcOEPaQSsx'},
#  {'artist_id': '2zvJLk0gTH7r7A5Q6X5Bq8',
#   'artist_name': 'Javed-Mohsin',
#   'external_url': 'https://api.spotify.com/v1/artists/2zvJLk0gTH7r7A5Q6X5Bq8'},
#  {'artist_id': '5wJ1H6ud777odtZl5gG507',
#   'artist_name': 'Vishal Mishra',
#   'external_url': 'https://api.spotify.com/v1/artists/5wJ1H6ud777odtZl5gG507'},
#  {'artist_id': '0oOet2f43PA68X5RxKobEy',
#   'artist_name': 'Shreya Ghoshal',
#   'external_url': 'https://api.spotify.com/v1/artists/0oOet2f43PA68X5RxKobEy'},
#  {'artist_id': '1n9EM0Y4A89vuRiA93gSS9',
#   'artist_name': 'Kaifi Khalil',
#   'external_url': 'https://api.spotify.com/v1/artists/1n9EM0Y4A89vuRiA93gSS9'},
#  {'artist_id': '1SyKki7JI1AZNKwgNMkn25',
#   'artist_name': 'Sachet-Parampara',
#   'external_url': 'https://api.spotify.com/v1/artists/1SyKki7JI1AZNKwgNMkn25'},
#  {'artist_id': '6WOdPJmexxFINcKMkP2jMG',
#   'artist_name': 'Sachet Tandon',
#   'external_url': 'https://api.spotify.com/v1/artists/6WOdPJmexxFINcKMkP2jMG'},
#  {'artist_id': '1E6arsXf5Fgsnv9YpSzjpE',
#   'artist_name': 'Parampara Tandon',
#   'external_url': 'https://api.spotify.com/v1/artists/1E6arsXf5Fgsnv9YpSzjpE'},
#  {'artist_id': '3gBKY0y3dFFVRqicLnVZYz',
#   'artist_name': 'Alka Yagnik',
#   'external_url': 'https://api.spotify.com/v1/artists/3gBKY0y3dFFVRqicLnVZYz'},
#  {'artist_id': '4YRxDV8wJFPHPTeXepOstw',
#   'artist_name': 'Arijit Singh',
#   'external_url': 'https://api.spotify.com/v1/artists/4YRxDV8wJFPHPTeXepOstw'},
#  {'artist_id': '5r3wPya2PpeTTsXsGhQU8O',
#   'artist_name': 'Shubh',
#   'external_url': 'https://api.spotify.com/v1/artists/5r3wPya2PpeTTsXsGhQU8O'},
#  {'artist_id': '1wRPtKGflJrBx9BmLsSwlU',
#   'artist_name': 'Pritam',
#   'external_url': 'https://api.spotify.com/v1/artists/1wRPtKGflJrBx9BmLsSwlU'},
#  {'artist_id': '4YRxDV8wJFPHPTeXepOstw',
#   'artist_name': 'Arijit Singh',
#   'external_url': 'https://api.spotify.com/v1/artists/4YRxDV8wJFPHPTeXepOstw'},
#  {'artist_id': '2fMqTqiTxUDlmcOEPaQSsx',
#   'artist_name': 'Amitabh Bhattacharya',
#   'external_url': 'https://api.spotify.com/v1/artists/2fMqTqiTxUDlmcOEPaQSsx'},
#  {'artist_id': '3tPQOjkxO3mrYrrgkTeXgH',
#   'artist_name': 'Nikhita Gandhi',
#   'external_url': 'https://api.spotify.com/v1/artists/3tPQOjkxO3mrYrrgkTeXgH'},
#  {'artist_id': '1wRPtKGflJrBx9BmLsSwlU',
#   'artist_name': 'Pritam',
#   'external_url': 'https://api.spotify.com/v1/artists/1wRPtKGflJrBx9BmLsSwlU'},
#  {'artist_id': '4YRxDV8wJFPHPTeXepOstw',
#   'artist_name': 'Arijit Singh',
#   'external_url': 'https://api.spotify.com/v1/artists/4YRxDV8wJFPHPTeXepOstw'},
#  {'artist_id': '19LIHDDSHBD5NyYHI3gpzB',
#   'artist_name': 'Shilpa Rao',
#   'external_url': 'https://api.spotify.com/v1/artists/19LIHDDSHBD5NyYHI3gpzB'},
#  {'artist_id': '5r3wPya2PpeTTsXsGhQU8O',
#   'artist_name': 'Shubh',
#   'external_url': 'https://api.spotify.com/v1/artists/5r3wPya2PpeTTsXsGhQU8O'},
#  {'artist_id': '56SjZARoEvag3RoKWIb16j',
#   'artist_name': 'B Praak',
#   'external_url': 'https://api.spotify.com/v1/artists/56SjZARoEvag3RoKWIb16j'},
#  {'artist_id': '5gZhfbckaWo89OzDSk3gdT',
#   'artist_name': 'Jaani',
#   'external_url': 'https://api.spotify.com/v1/artists/5gZhfbckaWo89OzDSk3gdT'},
#  {'artist_id': '1sSYaQBOI71QZDZ9OWW3hp',
#   'artist_name': 'Chani Nattan',
#   'external_url': 'https://api.spotify.com/v1/artists/1sSYaQBOI71QZDZ9OWW3hp'},
#  {'artist_id': '4Lk9Mory8nRTolPO1TMMcN',
#   'artist_name': 'Inderpal Moga',
#   'external_url': 'https://api.spotify.com/v1/artists/4Lk9Mory8nRTolPO1TMMcN'},
#  {'artist_id': '6Mv8GjQa7LKUGCAqa9qqdb',
#   'artist_name': 'Vishal-Shekhar',
#   'external_url': 'https://api.spotify.com/v1/artists/6Mv8GjQa7LKUGCAqa9qqdb'},
#  {'artist_id': '4YRxDV8wJFPHPTeXepOstw',
#   'artist_name': 'Arijit Singh',
#   'external_url': 'https://api.spotify.com/v1/artists/4YRxDV8wJFPHPTeXepOstw'},
#  {'artist_id': '3FgHkfb3IqG4WKuVe1xCXM',
#   'artist_name': 'Sukriti Kakar',
#   'external_url': 'https://api.spotify.com/v1/artists/3FgHkfb3IqG4WKuVe1xCXM'},
#  {'artist_id': '6CXEwIaXYfVJ84biCxqc9k',
#   'artist_name': 'Vishal Dadlani',
#   'external_url': 'https://api.spotify.com/v1/artists/6CXEwIaXYfVJ84biCxqc9k'},
#  {'artist_id': '4xd7mLI7urqrxELaXhAvzw',
#   'artist_name': 'Shekhar Ravjiani',
#   'external_url': 'https://api.spotify.com/v1/artists/4xd7mLI7urqrxELaXhAvzw'},
#  {'artist_id': '0m3D4grap8VFSzbJMqgNVk',
#   'artist_name': 'Kumaar',
#   'external_url': 'https://api.spotify.com/v1/artists/0m3D4grap8VFSzbJMqgNVk'},
#  {'artist_id': '5NHm4TU5Twz7owibYxJfFU',
#   'artist_name': 'King',
#   'external_url': 'https://api.spotify.com/v1/artists/5NHm4TU5Twz7owibYxJfFU'},
#  {'artist_id': '4wwYGgSpeBtvk5WX6HBqzw',
#   'artist_name': 'Aditya A',
#   'external_url': 'https://api.spotify.com/v1/artists/4wwYGgSpeBtvk5WX6HBqzw'},
#  {'artist_id': '5r3wPya2PpeTTsXsGhQU8O',
#   'artist_name': 'Shubh',
#   'external_url': 'https://api.spotify.com/v1/artists/5r3wPya2PpeTTsXsGhQU8O'},
#  {'artist_id': '3nqS8jzqmsPKFJTp0BOIel',
#   'artist_name': 'Ikky',
#   'external_url': 'https://api.spotify.com/v1/artists/3nqS8jzqmsPKFJTp0BOIel'},
#  {'artist_id': '1wRPtKGflJrBx9BmLsSwlU',
#   'artist_name': 'Pritam',
#   'external_url': 'https://api.spotify.com/v1/artists/1wRPtKGflJrBx9BmLsSwlU'},
#  {'artist_id': '4YRxDV8wJFPHPTeXepOstw',
#   'artist_name': 'Arijit Singh',
#   'external_url': 'https://api.spotify.com/v1/artists/4YRxDV8wJFPHPTeXepOstw'},
#  {'artist_id': '2fMqTqiTxUDlmcOEPaQSsx',
#   'artist_name': 'Amitabh Bhattacharya',
#   'external_url': 'https://api.spotify.com/v1/artists/2fMqTqiTxUDlmcOEPaQSsx'},
#  {'artist_id': '3hbwOFtgWSNfeRzF2o7Y65',
#   'artist_name': 'Charan',
#   'external_url': 'https://api.spotify.com/v1/artists/3hbwOFtgWSNfeRzF2o7Y65'},
#  {'artist_id': '3lmszXxkp47K9kDCRRPU8p',
#   'artist_name': 'Laddi Chahal',
#   'external_url': 'https://api.spotify.com/v1/artists/3lmszXxkp47K9kDCRRPU8p'},
#  {'artist_id': '3OQRPFFS3OsltFjFAXu1kE',
#   'artist_name': 'Parmish Verma',
#   'external_url': 'https://api.spotify.com/v1/artists/3OQRPFFS3OsltFjFAXu1kE'},
#  {'artist_id': '55kkrbuMkdzPGD7YGA6xrJ',
#   'artist_name': 'Gurlez Akhtar',
#   'external_url': 'https://api.spotify.com/v1/artists/55kkrbuMkdzPGD7YGA6xrJ'},
#  {'artist_id': '4f7KfxeHq9BiylGmyXepGt',
#   'artist_name': 'Tanishk Bagchi',
#   'external_url': 'https://api.spotify.com/v1/artists/4f7KfxeHq9BiylGmyXepGt'},
#  {'artist_id': '1tqysapcCh1lWEAc9dIFpa',
#   'artist_name': 'Jubin Nautiyal',
#   'external_url': 'https://api.spotify.com/v1/artists/1tqysapcCh1lWEAc9dIFpa'},
#  {'artist_id': '1sVmXkzX2ukc6QvasrDBES',
#   'artist_name': 'Asees Kaur',
#   'external_url': 'https://api.spotify.com/v1/artists/1sVmXkzX2ukc6QvasrDBES'},
#  {'artist_id': '4PULA4EFzYTrxYvOVlwpiQ',
#   'artist_name': 'Sidhu Moose Wala',
#   'external_url': 'https://api.spotify.com/v1/artists/4PULA4EFzYTrxYvOVlwpiQ'},
#  {'artist_id': '4YRxDV8wJFPHPTeXepOstw',
#   'artist_name': 'Arijit Singh',
#   'external_url': 'https://api.spotify.com/v1/artists/4YRxDV8wJFPHPTeXepOstw'},
#  {'artist_id': '09UmIX92EUH9hAK4bxvHx6',
#   'artist_name': 'Mithoon',
#   'external_url': 'https://api.spotify.com/v1/artists/09UmIX92EUH9hAK4bxvHx6'},
#  {'artist_id': '2FKWNmZWDBZR4dE5KX4plR',
#   'artist_name': 'Diljit Dosanjh',
#   'external_url': 'https://api.spotify.com/v1/artists/2FKWNmZWDBZR4dE5KX4plR'},
#  {'artist_id': '6LEG9Ld1aLImEFEVHdWNSB',
#   'artist_name': 'AP Dhillon',
#   'external_url': 'https://api.spotify.com/v1/artists/6LEG9Ld1aLImEFEVHdWNSB'},
#  {'artist_id': '5DHi2MeoRgAwPE0A0qwRMl',
#   'artist_name': 'Gurinder Gill',
#   'external_url': 'https://api.spotify.com/v1/artists/5DHi2MeoRgAwPE0A0qwRMl'},
#  {'artist_id': '74RGMjbSsFv5RLj8wVx9Yv',
#   'artist_name': 'Sharn',
#   'external_url': 'https://api.spotify.com/v1/artists/74RGMjbSsFv5RLj8wVx9Yv'},
#  {'artist_id': '6nAMu7pGqdwUSsGMZPUvSk',
#   'artist_name': '40k',
#   'external_url': 'https://api.spotify.com/v1/artists/6nAMu7pGqdwUSsGMZPUvSk'},
#  {'artist_id': '1i31OYo0s5VoMCaMRJFZkJ',
#   'artist_name': 'The Paul',
#   'external_url': 'https://api.spotify.com/v1/artists/1i31OYo0s5VoMCaMRJFZkJ'},
#  {'artist_id': '4C19flKmMm12gRxmBJWMCV',
#   'artist_name': 'Varinder Brar',
#   'external_url': 'https://api.spotify.com/v1/artists/4C19flKmMm12gRxmBJWMCV'},
#  {'artist_id': '3quojFCZjKk1j5zIv0HX2P',
#   'artist_name': 'Rav Dhaliwal',
#   'external_url': 'https://api.spotify.com/v1/artists/3quojFCZjKk1j5zIv0HX2P'},
#  {'artist_id': '2YzXsQoI3rqYNEVd4nac7g',
#   'artist_name': 'Ultra Beats',
#   'external_url': 'https://api.spotify.com/v1/artists/2YzXsQoI3rqYNEVd4nac7g'},
#  {'artist_id': '6LEG9Ld1aLImEFEVHdWNSB',
#   'artist_name': 'AP Dhillon',
#   'external_url': 'https://api.spotify.com/v1/artists/6LEG9Ld1aLImEFEVHdWNSB'},
#  {'artist_id': '5DHi2MeoRgAwPE0A0qwRMl',
#   'artist_name': 'Gurinder Gill',
#   'external_url': 'https://api.spotify.com/v1/artists/5DHi2MeoRgAwPE0A0qwRMl'},
#  {'artist_id': '0OS0NZnK7TGIAWx8MkWNFN',
#   'artist_name': 'Intense',
#   'external_url': 'https://api.spotify.com/v1/artists/0OS0NZnK7TGIAWx8MkWNFN'},
#  {'artist_id': '2vJvM1hPBYqDoGBje0kRMd',
#   'artist_name': 'Jassa Dhillon',
#   'external_url': 'https://api.spotify.com/v1/artists/2vJvM1hPBYqDoGBje0kRMd'},
#  {'artist_id': '54BjV0qctcWp8xOip7uaJD',
#   'artist_name': 'thiarajxtt',
#   'external_url': 'https://api.spotify.com/v1/artists/54BjV0qctcWp8xOip7uaJD'},
#  {'artist_id': '6Mv8GjQa7LKUGCAqa9qqdb',
#   'artist_name': 'Vishal-Shekhar',
#   'external_url': 'https://api.spotify.com/v1/artists/6Mv8GjQa7LKUGCAqa9qqdb'},
#  {'artist_id': '19LIHDDSHBD5NyYHI3gpzB',
#   'artist_name': 'Shilpa Rao',
#   'external_url': 'https://api.spotify.com/v1/artists/19LIHDDSHBD5NyYHI3gpzB'},
#  {'artist_id': '2Yf4MRVpt0rcAd5y5h5ph1',
#   'artist_name': 'Caralisa Monteiro',
#   'external_url': 'https://api.spotify.com/v1/artists/2Yf4MRVpt0rcAd5y5h5ph1'},
#  {'artist_id': '6CXEwIaXYfVJ84biCxqc9k',
#   'artist_name': 'Vishal Dadlani',
#   'external_url': 'https://api.spotify.com/v1/artists/6CXEwIaXYfVJ84biCxqc9k'},
#  {'artist_id': '4xd7mLI7urqrxELaXhAvzw',
#   'artist_name': 'Shekhar Ravjiani',
#   'external_url': 'https://api.spotify.com/v1/artists/4xd7mLI7urqrxELaXhAvzw'},
#  {'artist_id': '0m3D4grap8VFSzbJMqgNVk',
#   'artist_name': 'Kumaar',
#   'external_url': 'https://api.spotify.com/v1/artists/0m3D4grap8VFSzbJMqgNVk'},
#  {'artist_id': '4gdMJYnopf2nEUcanAwstx',
#   'artist_name': 'Anuv Jain',
#   'external_url': 'https://api.spotify.com/v1/artists/4gdMJYnopf2nEUcanAwstx'},
#  {'artist_id': '2zvJLk0gTH7r7A5Q6X5Bq8',
#   'artist_name': 'Javed-Mohsin',
#   'external_url': 'https://api.spotify.com/v1/artists/2zvJLk0gTH7r7A5Q6X5Bq8'},
#  {'artist_id': '4YRxDV8wJFPHPTeXepOstw',
#   'artist_name': 'Arijit Singh',
#   'external_url': 'https://api.spotify.com/v1/artists/4YRxDV8wJFPHPTeXepOstw'},
#  {'artist_id': '0oOet2f43PA68X5RxKobEy',
#   'artist_name': 'Shreya Ghoshal',
#   'external_url': 'https://api.spotify.com/v1/artists/0oOet2f43PA68X5RxKobEy'},
#  {'artist_id': '52XgeWw24o4klNdfwvB0Vx',
#   'artist_name': 'Kunaal Vermaa',
#   'external_url': 'https://api.spotify.com/v1/artists/52XgeWw24o4klNdfwvB0Vx'},
#  {'artist_id': '74OaRjmyh0XyRZsQQQ5l7c',
#   'artist_name': 'Jasleen Royal',
#   'external_url': 'https://api.spotify.com/v1/artists/74OaRjmyh0XyRZsQQQ5l7c'},
#  {'artist_id': '56SjZARoEvag3RoKWIb16j',
#   'artist_name': 'B Praak',
#   'external_url': 'https://api.spotify.com/v1/artists/56SjZARoEvag3RoKWIb16j'},
#  {'artist_id': '0bRPtPZQkWHeG7MGk9eWlh',
#   'artist_name': 'Romy',
#   'external_url': 'https://api.spotify.com/v1/artists/0bRPtPZQkWHeG7MGk9eWlh'},
#  {'artist_id': '4nJ0kto93jDLHQKmpGeYS8',
#   'artist_name': 'Anvita Dutt',
#   'external_url': 'https://api.spotify.com/v1/artists/4nJ0kto93jDLHQKmpGeYS8'},
#  {'artist_id': '5wJ1H6ud777odtZl5gG507',
#   'artist_name': 'Vishal Mishra',
#   'external_url': 'https://api.spotify.com/v1/artists/5wJ1H6ud777odtZl5gG507'},
#  {'artist_id': '1wRPtKGflJrBx9BmLsSwlU',
#   'artist_name': 'Pritam',
#   'external_url': 'https://api.spotify.com/v1/artists/1wRPtKGflJrBx9BmLsSwlU'},
#  {'artist_id': '4YRxDV8wJFPHPTeXepOstw',
#   'artist_name': 'Arijit Singh',
#   'external_url': 'https://api.spotify.com/v1/artists/4YRxDV8wJFPHPTeXepOstw'},
#  {'artist_id': '4GJ6xDCF5jaUqD6avOuQT6',
#   'artist_name': 'FIFTY FIFTY',
#   'external_url': 'https://api.spotify.com/v1/artists/4GJ6xDCF5jaUqD6avOuQT6'},
#  {'artist_id': '1yzgJmZf5CxtFfGfRFm4Si',
#   'artist_name': 'Gajendra Verma',
#   'external_url': 'https://api.spotify.com/v1/artists/1yzgJmZf5CxtFfGfRFm4Si'},
#  {'artist_id': '6zZrFenNe3YPttxZsnQQs1',
#   'artist_name': 'Akhil',
#   'external_url': 'https://api.spotify.com/v1/artists/6zZrFenNe3YPttxZsnQQs1'},
#  {'artist_id': '1OPqAyxsQc8mcRmoNBAnVk',
#   'artist_name': 'Dhvani Bhanushali',
#   'external_url': 'https://api.spotify.com/v1/artists/1OPqAyxsQc8mcRmoNBAnVk'},
#  {'artist_id': '52XgeWw24o4klNdfwvB0Vx',
#   'artist_name': 'Kunaal Vermaa',
#   'external_url': 'https://api.spotify.com/v1/artists/52XgeWw24o4klNdfwvB0Vx'},
#  {'artist_id': '5wJ1H6ud777odtZl5gG507',
#   'artist_name': 'Vishal Mishra',
#   'external_url': 'https://api.spotify.com/v1/artists/5wJ1H6ud777odtZl5gG507'},
#  {'artist_id': '7kjSuFGKhLm8b5qXoMhRkJ',
#   'artist_name': 'Libianca',
#   'external_url': 'https://api.spotify.com/v1/artists/7kjSuFGKhLm8b5qXoMhRkJ'},
#  {'artist_id': '1mBydYMVBECdDmMfE2sEUO',
#   'artist_name': 'Sachin-Jigar',
#   'external_url': 'https://api.spotify.com/v1/artists/1mBydYMVBECdDmMfE2sEUO'},
#  {'artist_id': '0oOet2f43PA68X5RxKobEy',
#   'artist_name': 'Shreya Ghoshal',
#   'external_url': 'https://api.spotify.com/v1/artists/0oOet2f43PA68X5RxKobEy'},
#  {'artist_id': '6k6dimE4a6OFnD0HWmkIUW',
#   'artist_name': 'Tochi Raina',
#   'external_url': 'https://api.spotify.com/v1/artists/6k6dimE4a6OFnD0HWmkIUW'},
#  {'artist_id': '3Nrfpe0tUJi4K4DXYWgMUX',
#   'artist_name': 'BTS',
#   'external_url': 'https://api.spotify.com/v1/artists/3Nrfpe0tUJi4K4DXYWgMUX'},
#  {'artist_id': '0uOUeC51AxGnP6hB8gurwt',
#   'artist_name': 'Cheema Y',
#   'external_url': 'https://api.spotify.com/v1/artists/0uOUeC51AxGnP6hB8gurwt'},
#  {'artist_id': '0QntOArZgiNHoemAzwJPu5',
#   'artist_name': 'Gur Sidhu',
#   'external_url': 'https://api.spotify.com/v1/artists/0QntOArZgiNHoemAzwJPu5'},
#  {'artist_id': '1wRPtKGflJrBx9BmLsSwlU',
#   'artist_name': 'Pritam',
#   'external_url': 'https://api.spotify.com/v1/artists/1wRPtKGflJrBx9BmLsSwlU'},
#  {'artist_id': '4YRxDV8wJFPHPTeXepOstw',
#   'artist_name': 'Arijit Singh',
#   'external_url': 'https://api.spotify.com/v1/artists/4YRxDV8wJFPHPTeXepOstw'},
#  {'artist_id': '2fMqTqiTxUDlmcOEPaQSsx',
#   'artist_name': 'Amitabh Bhattacharya',
#   'external_url': 'https://api.spotify.com/v1/artists/2fMqTqiTxUDlmcOEPaQSsx'},
#  {'artist_id': '00sCATpEvwH48ays7PlQFU',
#   'artist_name': 'Jonita Gandhi',
#   'external_url': 'https://api.spotify.com/v1/artists/00sCATpEvwH48ays7PlQFU'},
#  {'artist_id': '1Xyo4u8uXC1ZmMpatF05PJ',
#   'artist_name': 'The Weeknd',
#   'external_url': 'https://api.spotify.com/v1/artists/1Xyo4u8uXC1ZmMpatF05PJ'},
#  {'artist_id': '4tZwfgrHOc3mvqYlEYSvVi',
#   'artist_name': 'Daft Punk',
#   'external_url': 'https://api.spotify.com/v1/artists/4tZwfgrHOc3mvqYlEYSvVi'},
#  {'artist_id': '4YRxDV8wJFPHPTeXepOstw',
#   'artist_name': 'Arijit Singh',
#   'external_url': 'https://api.spotify.com/v1/artists/4YRxDV8wJFPHPTeXepOstw'}]

# %%
song_list = []
for row in data['items']:
    song_id = row['track']['id']
    song_name = row['track']['name']
    song_duration = row['track']['duration_ms']
    song_url = row['track']['external_urls']['spotify']
    song_popularity = row['track']['popularity']
    song_added = row['added_at']
    album_id = row['track']['album']['id']
    artist_id = row['track']['album']['artists'][0]['id']
    song_element = {'song_id':song_id,'song_name':song_name,'duration_ms':song_duration,'url':song_url,
                    'popularity':song_popularity,'song_added':song_added,'album_id':album_id,
                    'artist_id':artist_id
                   }
    song_list.append(song_element)

# %%
song_list
# Out:
# [{'song_id': '7Ky9U9iHjGBiRax3joCRDS',
#   'song_name': 'Phir Aur Kya Chahiye (From "Zara Hatke Zara Bachke")',
#   'duration_ms': 266075,
#   'url': 'https://open.spotify.com/track/7Ky9U9iHjGBiRax3joCRDS',
#   'popularity': 66,
#   'song_added': '2023-06-12T09:44:12Z',
#   'album_id': '1skD49xUwXnHLMrlEKTo6j',
#   'artist_id': '1mBydYMVBECdDmMfE2sEUO'},
#  {'song_id': '5GhNEr3AQtMhHGYLRgCSV5',
#   'song_name': 'Tere Vaaste',
#   'duration_ms': 189136,
#   'url': 'https://open.spotify.com/track/5GhNEr3AQtMhHGYLRgCSV5',
#   'popularity': 56,
#   'song_added': '2023-06-12T09:44:12Z',
#   'album_id': '6Yb13Od1beXcshjO6vSskt',
#   'artist_id': '1mBydYMVBECdDmMfE2sEUO'},
#  {'song_id': '6Z4rRhYZVQsYKmrxD40tru',
#   'song_name': 'Obsessed',
#   'duration_ms': 190444,
#   'url': 'https://open.spotify.com/track/6Z4rRhYZVQsYKmrxD40tru',
#   'popularity': 84,
#   'song_added': '2023-06-12T09:44:12Z',
#   'album_id': '3LyafXRRJVEfcjTMr1N8Mu',
#   'artist_id': '34gAaWeYZoRER7MY3KBy1Q'},
#  {'song_id': '6oz1L5jcqZWYuId7nxvIan',
#   'song_name': 'Still Rollin',
#   'duration_ms': 174730,
#   'url': 'https://open.spotify.com/track/6oz1L5jcqZWYuId7nxvIan',
#   'popularity': 81,
#   'song_added': '2023-06-12T09:44:12Z',
#   'album_id': '5AivaZj0CiQJoDWqVH2pbh',
#   'artist_id': '5r3wPya2PpeTTsXsGhQU8O'},
#  {'song_id': '1418IuVKQPTYqt7QNJ9RXN',
#   'song_name': 'Maan Meri Jaan',
#   'duration_ms': 194653,
#   'url': 'https://open.spotify.com/track/1418IuVKQPTYqt7QNJ9RXN',
#   'popularity': 86,
#   'song_added': '2023-06-12T09:44:12Z',
#   'album_id': '15CyNDuGY5fsG0Hn9rjnpG',
#   'artist_id': '5NHm4TU5Twz7owibYxJfFU'},
#  {'song_id': '0czcoKJbJt08NqKrvSbbz7',
#   'song_name': 'O Bedardeya (From "Tu Jhoothi Main Makkaar")',
#   'duration_ms': 313051,
#   'url': 'https://open.spotify.com/track/0czcoKJbJt08NqKrvSbbz7',
#   'popularity': 86,
#   'song_added': '2023-06-12T09:44:12Z',
#   'album_id': '7kXEDaT5yy8IUT7Fmqs1i2',
#   'artist_id': '1wRPtKGflJrBx9BmLsSwlU'},
#  {'song_id': '73K33p4Vyz9koXGqmL5eFs',
#   'song_name': 'Malang Sajna',
#   'duration_ms': 161041,
#   'url': 'https://open.spotify.com/track/73K33p4Vyz9koXGqmL5eFs',
#   'popularity': 84,
#   'song_added': '2023-06-12T09:44:12Z',
#   'album_id': '7khRLZe8P6XcUoRgOa3nnf',
#   'artist_id': '6WOdPJmexxFINcKMkP2jMG'},
#  {'song_id': '4UMIv5jd9gK98a39BQRD9X',
#   'song_name': 'Kesariya',
#   'duration_ms': 268164,
#   'url': 'https://open.spotify.com/track/4UMIv5jd9gK98a39BQRD9X',
#   'popularity': 79,
#   'song_added': '2023-06-12T09:44:12Z',
#   'album_id': '4kIPlpwEZBK9JaI9pZHe79',
#   'artist_id': '1wRPtKGflJrBx9BmLsSwlU'},
#  {'song_id': '51DEaelXeJJ6cFFYbX8Hal',
#   'song_name': 'Zihaal e Miskin',
#   'duration_ms': 243953,
#   'url': 'https://open.spotify.com/track/51DEaelXeJJ6cFFYbX8Hal',
#   'popularity': 76,
#   'song_added': '2023-06-12T09:44:12Z',
#   'album_id': '54ubCIO3voLnU7ZmJhxqBd',
#   'artist_id': '2zvJLk0gTH7r7A5Q6X5Bq8'},
#  {'song_id': '4VsP4Dm8gsibRxB5I2hEkw',
#   'song_name': 'Kahani Suno 2.0',
#   'duration_ms': 173637,
#   'url': 'https://open.spotify.com/track/4VsP4Dm8gsibRxB5I2hEkw',
#   'popularity': 85,
#   'song_added': '2023-06-12T09:44:12Z',
#   'album_id': '6BHlJhCk1vjCG6hqTG2SFV',
#   'artist_id': '1n9EM0Y4A89vuRiA93gSS9'},
#  {'song_id': '5aMLADD1Ho6Ogq8s8mIzB9',
#   'song_name': 'Ram Siya Ram (From "Adipurush")',
#   'duration_ms': 230092,
#   'url': 'https://open.spotify.com/track/5aMLADD1Ho6Ogq8s8mIzB9',
#   'popularity': 73,
#   'song_added': '2023-06-12T09:44:12Z',
#   'album_id': '25OmZbss1JS6CdFqFDiaNu',
#   'artist_id': '1SyKki7JI1AZNKwgNMkn25'},
#  {'song_id': '2FCXQHugkoHE1K3tiDu8pu',
#   'song_name': 'Agar Tum Saath Ho (From "Tamasha")',
#   'duration_ms': 341054,
#   'url': 'https://open.spotify.com/track/2FCXQHugkoHE1K3tiDu8pu',
#   'popularity': 80,
#   'song_added': '2023-06-12T09:44:12Z',
#   'album_id': '5Wm1nhxZqx7i0Hp6ZBqe9T',
#   'artist_id': '4YRxDV8wJFPHPTeXepOstw'},
#  {'song_id': '4eBvRhTJ2AcxCsbfTUjoRp',
#   'song_name': 'Cheques',
#   'duration_ms': 183756,
#   'url': 'https://open.spotify.com/track/4eBvRhTJ2AcxCsbfTUjoRp',
#   'popularity': 77,
#   'song_added': '2023-06-12T09:44:12Z',
#   'album_id': '5AivaZj0CiQJoDWqVH2pbh',
#   'artist_id': '5r3wPya2PpeTTsXsGhQU8O'},
#  {'song_id': '2ZD4aIEepqZsdxPxLSuUhm',
#   'song_name': 'Tere Pyaar Mein',
#   'duration_ms': 266094,
#   'url': 'https://open.spotify.com/track/2ZD4aIEepqZsdxPxLSuUhm',
#   'popularity': 85,
#   'song_added': '2023-06-12T09:44:12Z',
#   'album_id': '5uAi4ZZc7zRdd6PsKNcJXO',
#   'artist_id': '1wRPtKGflJrBx9BmLsSwlU'},
#  {'song_id': '4blqlsA1uf2d2I40E90EUC',
#   'song_name': 'Tere Hawaale (From "Laal Singh Chaddha")',
#   'duration_ms': 346290,
#   'url': 'https://open.spotify.com/track/4blqlsA1uf2d2I40E90EUC',
#   'popularity': 79,
#   'song_added': '2023-06-12T09:44:12Z',
#   'album_id': '1lZk7TnMgvS3mSlfeWW1b3',
#   'artist_id': '1wRPtKGflJrBx9BmLsSwlU'},
#  {'song_id': '08Isz2ETWSBhvIl8UpKYsp',
#   'song_name': 'No Love',
#   'duration_ms': 170387,
#   'url': 'https://open.spotify.com/track/08Isz2ETWSBhvIl8UpKYsp',
#   'popularity': 83,
#   'song_added': '2023-06-12T09:44:12Z',
#   'album_id': '5Zcgog7sQ79ISF32y9nABU',
#   'artist_id': '5r3wPya2PpeTTsXsGhQU8O'},
#  {'song_id': '6t7PuZfHAtNGheWisgUq3I',
#   'song_name': 'Kya Loge Tum',
#   'duration_ms': 233684,
#   'url': 'https://open.spotify.com/track/6t7PuZfHAtNGheWisgUq3I',
#   'popularity': 80,
#   'song_added': '2023-06-12T09:44:12Z',
#   'album_id': '76spwPLkGkvPtADGCTkNeT',
#   'artist_id': '56SjZARoEvag3RoKWIb16j'},
#  {'song_id': '3wz2vWhYnnBoFmgMkqtzLy',
#   'song_name': 'Daku',
#   'duration_ms': 131077,
#   'url': 'https://open.spotify.com/track/3wz2vWhYnnBoFmgMkqtzLy',
#   'popularity': 83,
#   'song_added': '2023-06-12T09:44:12Z',
#   'album_id': '3RaIXDlIRvziryGLXm8lBR',
#   'artist_id': '1sSYaQBOI71QZDZ9OWW3hp'},
#  {'song_id': '6FAYpZ4jve8vpvTwUvjK6H',
#   'song_name': 'Jhoome Jo Pathaan',
#   'duration_ms': 208164,
#   'url': 'https://open.spotify.com/track/6FAYpZ4jve8vpvTwUvjK6H',
#   'popularity': 84,
#   'song_added': '2023-06-12T09:44:12Z',
#   'album_id': '2ooWY7xriwwyj23dAI32C2',
#   'artist_id': '6Mv8GjQa7LKUGCAqa9qqdb'},
#  {'song_id': '0yCWDaAgOtg6TKlNCg9rwA',
#   'song_name': 'Tu Aake Dekhle',
#   'duration_ms': 270000,
#   'url': 'https://open.spotify.com/track/0yCWDaAgOtg6TKlNCg9rwA',
#   'popularity': 83,
#   'song_added': '2023-06-12T09:44:12Z',
#   'album_id': '7uftfPn8f7lwtRLUrEVRYM',
#   'artist_id': '5NHm4TU5Twz7owibYxJfFU'},
#  {'song_id': '0snQrp1VaY5Pj1YIHRJpRJ',
#   'song_name': 'Chaand Baaliyan',
#   'duration_ms': 103264,
#   'url': 'https://open.spotify.com/track/0snQrp1VaY5Pj1YIHRJpRJ',
#   'popularity': 81,
#   'song_added': '2023-06-12T09:44:12Z',
#   'album_id': '6AJaDEafyyyWWXHZQtcFGe',
#   'artist_id': '4wwYGgSpeBtvk5WX6HBqzw'},
#  {'song_id': '42TMa2hgBNjte4uV7jNCnQ',
#   'song_name': 'Baller',
#   'duration_ms': 148188,
#   'url': 'https://open.spotify.com/track/42TMa2hgBNjte4uV7jNCnQ',
#   'popularity': 83,
#   'song_added': '2023-06-12T09:44:12Z',
#   'album_id': '44aCFqUbG06fL58kqpMp8p',
#   'artist_id': '3nqS8jzqmsPKFJTp0BOIel'},
#  {'song_id': '2vPrBucKCfKmafHhSfJ2pt',
#   'song_name': 'Pyaar Hota Kayi Baar Hai (From "Tu Jhoothi Main Makkaar")',
#   'duration_ms': 216270,
#   'url': 'https://open.spotify.com/track/2vPrBucKCfKmafHhSfJ2pt',
#   'popularity': 82,
#   'song_added': '2023-06-12T09:44:12Z',
#   'album_id': '1cttjZoENYipDCPgISthpY',
#   'artist_id': '1wRPtKGflJrBx9BmLsSwlU'},
#  {'song_id': '03yKEFruN3BS2coglBtt2N',
#   'song_name': 'Rubicon Drill',
#   'duration_ms': 188571,
#   'url': 'https://open.spotify.com/track/03yKEFruN3BS2coglBtt2N',
#   'popularity': 82,
#   'song_added': '2023-06-12T09:44:12Z',
#   'album_id': '4qlI6YM61j9NeGe832mExq',
#   'artist_id': '3lmszXxkp47K9kDCRRPU8p'},
#  {'song_id': '2rOnSn2piaqLAlYjtfUBlY',
#   'song_name': 'Raataan Lambiyan (From "Shershaah")',
#   'duration_ms': 230292,
#   'url': 'https://open.spotify.com/track/2rOnSn2piaqLAlYjtfUBlY',
#   'popularity': 79,
#   'song_added': '2023-06-12T09:44:12Z',
#   'album_id': '2DKSZvMj7Da6rzNVPMgREj',
#   'artist_id': '4f7KfxeHq9BiylGmyXepGt'},
#  {'song_id': '5W7DOVGQLTigu09afW7QMT',
#   'song_name': '295',
#   'duration_ms': 270000,
#   'url': 'https://open.spotify.com/track/5W7DOVGQLTigu09afW7QMT',
#   'popularity': 81,
#   'song_added': '2023-06-12T09:44:12Z',
#   'album_id': '45ZIondgVoMB84MQQaUo9T',
#   'artist_id': '4PULA4EFzYTrxYvOVlwpiQ'},
#  {'song_id': '2Fv2injs4qAm8mJBGaxVKU',
#   'song_name': 'Tujhe Kitna Chahne Lage (From "Kabir Singh")',
#   'duration_ms': 284779,
#   'url': 'https://open.spotify.com/track/2Fv2injs4qAm8mJBGaxVKU',
#   'popularity': 78,
#   'song_added': '2023-06-12T09:44:12Z',
#   'album_id': '3I8PdIhk6pNm8Kv0HiF14V',
#   'artist_id': '4YRxDV8wJFPHPTeXepOstw'},
#  {'song_id': '3ZGJhN4unVspOqpwGvUL2W',
#   'song_name': 'Lemonade',
#   'duration_ms': 166666,
#   'url': 'https://open.spotify.com/track/3ZGJhN4unVspOqpwGvUL2W',
#   'popularity': 80,
#   'song_added': '2023-06-12T09:44:12Z',
#   'album_id': '6KgPhunJItRDOhJFh6Sy78',
#   'artist_id': '2FKWNmZWDBZR4dE5KX4plR'},
#  {'song_id': '6TClJ8jXi3OBV7gcrU3jx5',
#   'song_name': 'TERE TE',
#   'duration_ms': 114418,
#   'url': 'https://open.spotify.com/track/6TClJ8jXi3OBV7gcrU3jx5',
#   'popularity': 79,
#   'song_added': '2023-06-12T09:44:12Z',
#   'album_id': '3fOswFPlmSWKTTFTlksdiv',
#   'artist_id': '0LyfQWJT6nXafLPZqxe9Of'},
#  {'song_id': '24MMjyA3NLqCsDJfsn51eg',
#   'song_name': 'Mi Amor',
#   'duration_ms': 203048,
#   'url': 'https://open.spotify.com/track/24MMjyA3NLqCsDJfsn51eg',
#   'popularity': 80,
#   'song_added': '2023-06-12T09:44:12Z',
#   'album_id': '0azGrKHPYvl2MEKwQFfbV2',
#   'artist_id': '74RGMjbSsFv5RLj8wVx9Yv'},
#  {'song_id': '2NmBCDkjvJVvEZkH5QDOeb',
#   'song_name': 'Thaa',
#   'duration_ms': 181340,
#   'url': 'https://open.spotify.com/track/2NmBCDkjvJVvEZkH5QDOeb',
#   'popularity': 80,
#   'song_added': '2023-06-12T09:44:12Z',
#   'album_id': '6u5RdRVp5HBStyPRWvHcgm',
#   'artist_id': '4C19flKmMm12gRxmBJWMCV'},
#  {'song_id': '29m79w9xPMH4YCD6r8JSmV',
#   'song_name': 'Excuses',
#   'duration_ms': 176232,
#   'url': 'https://open.spotify.com/track/29m79w9xPMH4YCD6r8JSmV',
#   'popularity': 81,
#   'song_added': '2023-06-12T09:44:12Z',
#   'album_id': '3GkXRRRkV3rfgwG1wJset9',
#   'artist_id': '6LEG9Ld1aLImEFEVHdWNSB'},
#  {'song_id': '4ZVtid5khBfDx6Co0vTUE6',
#   'song_name': 'SPAIN',
#   'duration_ms': 104006,
#   'url': 'https://open.spotify.com/track/4ZVtid5khBfDx6Co0vTUE6',
#   'popularity': 80,
#   'song_added': '2023-06-12T09:44:12Z',
#   'album_id': '2GPHbR6aZ2rZooX6dF1nwB',
#   'artist_id': '2vJvM1hPBYqDoGBje0kRMd'},
#  {'song_id': '0CtZpaOhtzvLV3FfcsVpQo',
#   'song_name': 'Besharam Rang (From "Pathaan")',
#   'duration_ms': 258472,
#   'url': 'https://open.spotify.com/track/0CtZpaOhtzvLV3FfcsVpQo',
#   'popularity': 82,
#   'song_added': '2023-06-12T09:44:12Z',
#   'album_id': '5CvI5ppsG522pV554VLezD',
#   'artist_id': '6Mv8GjQa7LKUGCAqa9qqdb'},
#  {'song_id': '5iCY0TXNImK4hyKfcplQsg',
#   'song_name': 'Baarishein',
#   'duration_ms': 207309,
#   'url': 'https://open.spotify.com/track/5iCY0TXNImK4hyKfcplQsg',
#   'popularity': 79,
#   'song_added': '2023-06-12T09:44:12Z',
#   'album_id': '4ysOhipyMXKstywus51VXS',
#   'artist_id': '4gdMJYnopf2nEUcanAwstx'},
#  {'song_id': '5G7pZ8G8NFvS1MQ9H4L7dC',
#   'song_name': 'Pal',
#   'duration_ms': 247286,
#   'url': 'https://open.spotify.com/track/5G7pZ8G8NFvS1MQ9H4L7dC',
#   'popularity': 78,
#   'song_added': '2023-06-12T09:44:12Z',
#   'album_id': '4QCM8VlhhlwZtQ2Ew7gtIg',
#   'artist_id': '2zvJLk0gTH7r7A5Q6X5Bq8'},
#  {'song_id': '72zHuDxFQTjbL51qJQSA7j',
#   'song_name': 'Ranjha (From "Shershaah")',
#   'duration_ms': 228855,
#   'url': 'https://open.spotify.com/track/72zHuDxFQTjbL51qJQSA7j',
#   'popularity': 80,
#   'song_added': '2023-06-12T09:44:12Z',
#   'album_id': '0Z1zYMwJRpvq0d9rdqTOYo',
#   'artist_id': '0LyfQWJT6nXafLPZqxe9Of'},
#  {'song_id': '0UZLaEOSIc5kg0cc7eszqC',
#   'song_name': 'Manjha',
#   'duration_ms': 191647,
#   'url': 'https://open.spotify.com/track/0UZLaEOSIc5kg0cc7eszqC',
#   'popularity': 79,
#   'song_added': '2023-06-12T09:44:12Z',
#   'album_id': '1N9rGbn2M9lzU6YcJ6081E',
#   'artist_id': '5wJ1H6ud777odtZl5gG507'},
#  {'song_id': '1smFN2CLqGROu0J0UyvDfL',
#   'song_name': 'Shayad',
#   'duration_ms': 247941,
#   'url': 'https://open.spotify.com/track/1smFN2CLqGROu0J0UyvDfL',
#   'popularity': 78,
#   'song_added': '2023-06-12T09:44:12Z',
#   'album_id': '6IXfWhC7omotM4lt0ROmEr',
#   'artist_id': '1wRPtKGflJrBx9BmLsSwlU'},
#  {'song_id': '7FbrGaHYVDmfr7KoLIZnQ7',
#   'song_name': 'Cupid - Twin Ver.',
#   'duration_ms': 174253,
#   'url': 'https://open.spotify.com/track/7FbrGaHYVDmfr7KoLIZnQ7',
#   'popularity': 98,
#   'song_added': '2023-06-12T09:44:12Z',
#   'album_id': '5letLUZIFsQikJYShfGNs4',
#   'artist_id': '4GJ6xDCF5jaUqD6avOuQT6'},
#  {'song_id': '3yV2c3cYhkAwSsxAq6nRiv',
#   'song_name': 'Mann Mera',
#   'duration_ms': 200120,
#   'url': 'https://open.spotify.com/track/3yV2c3cYhkAwSsxAq6nRiv',
#   'popularity': 78,
#   'song_added': '2023-06-12T09:44:12Z',
#   'album_id': '7Gws1vUsWltRs58x8QuYVQ',
#   'artist_id': '1yzgJmZf5CxtFfGfRFm4Si'},
#  {'song_id': '2tjWCe2W7sgvS3C8NHcdtI',
#   'song_name': 'Duniyaa (From "Luka Chuppi")',
#   'duration_ms': 222500,
#   'url': 'https://open.spotify.com/track/2tjWCe2W7sgvS3C8NHcdtI',
#   'popularity': 77,
#   'song_added': '2023-06-12T09:44:12Z',
#   'album_id': '5hzAIEMlQpsEGIQFvnFOQx',
#   'artist_id': '6zZrFenNe3YPttxZsnQQs1'},
#  {'song_id': '1y1rQTkWmrZdJmjwuK07GC',
#   'song_name': 'Kaise Hua (From "Kabir Singh")',
#   'duration_ms': 234722,
#   'url': 'https://open.spotify.com/track/1y1rQTkWmrZdJmjwuK07GC',
#   'popularity': 76,
#   'song_added': '2023-06-12T09:44:12Z',
#   'album_id': '1ncyKqyZae6DoyjYaV9LmS',
#   'artist_id': '5wJ1H6ud777odtZl5gG507'},
#  {'song_id': '26b3oVLrRUaaybJulow9kz',
#   'song_name': 'People',
#   'duration_ms': 184791,
#   'url': 'https://open.spotify.com/track/26b3oVLrRUaaybJulow9kz',
#   'popularity': 93,
#   'song_added': '2023-06-12T09:44:12Z',
#   'album_id': '5Hmh6N8oisrcuZKa8EY5dn',
#   'artist_id': '7kjSuFGKhLm8b5qXoMhRkJ'},
#  {'song_id': '6udC4b4jOSnHb9ItnXgKLR',
#   'song_name': 'Saibo',
#   'duration_ms': 195253,
#   'url': 'https://open.spotify.com/track/6udC4b4jOSnHb9ItnXgKLR',
#   'popularity': 79,
#   'song_added': '2023-06-12T09:44:12Z',
#   'album_id': '2HZl13JCi3PIaqVlIkp4q6',
#   'artist_id': '1mBydYMVBECdDmMfE2sEUO'},
#  {'song_id': '5IAESfJjmOYu7cHyX557kz',
#   'song_name': 'Take Two',
#   'duration_ms': 229953,
#   'url': 'https://open.spotify.com/track/5IAESfJjmOYu7cHyX557kz',
#   'popularity': 87,
#   'song_added': '2023-06-12T09:44:12Z',
#   'album_id': '3jeQDa9OFZ6GndLindHx3k',
#   'artist_id': '3Nrfpe0tUJi4K4DXYWgMUX'},
#  {'song_id': '610keNiNVTIkYD0CqeSerg',
#   'song_name': 'California Love',
#   'duration_ms': 175686,
#   'url': 'https://open.spotify.com/track/610keNiNVTIkYD0CqeSerg',
#   'popularity': 74,
#   'song_added': '2023-06-12T09:44:12Z',
#   'album_id': '64MZHXV7IglO8LE8KplSRw',
#   'artist_id': '0uOUeC51AxGnP6hB8gurwt'},
#  {'song_id': '4SqPZorSDuUtvdJwVGeZRC',
#   'song_name': 'Deva Deva',
#   'duration_ms': 279107,
#   'url': 'https://open.spotify.com/track/4SqPZorSDuUtvdJwVGeZRC',
#   'popularity': 68,
#   'song_added': '2023-06-12T09:44:12Z',
#   'album_id': '4kIPlpwEZBK9JaI9pZHe79',
#   'artist_id': '1wRPtKGflJrBx9BmLsSwlU'},
#  {'song_id': '7MXVkk9YMctZqd1Srtv4MB',
#   'song_name': 'Starboy',
#   'duration_ms': 230453,
#   'url': 'https://open.spotify.com/track/7MXVkk9YMctZqd1Srtv4MB',
#   'popularity': 93,
#   'song_added': '2023-06-12T09:44:12Z',
#   'album_id': '2ODvWsOgouMbaA5xf0RkJe',
#   'artist_id': '1Xyo4u8uXC1ZmMpatF05PJ'},
#  {'song_id': '2PvaburAUlhNHxVhw5lvOq',
#   'song_name': 'Humdard (From "Ek Villain")',
#   'duration_ms': 260590,
#   'url': 'https://open.spotify.com/track/2PvaburAUlhNHxVhw5lvOq',
#   'popularity': 74,
#   'song_added': '2023-06-12T09:44:12Z',
#   'album_id': '1WwkojG9sjMSrFVz4D51W0',
#   'artist_id': '4YRxDV8wJFPHPTeXepOstw'}]

# %%
album_df = pd.DataFrame.from_dict(album_list)

# %%
album_df
# Out:
#                   album_id                                               name  \
# 0   1skD49xUwXnHLMrlEKTo6j  Phir Aur Kya Chahiye (From "Zara Hatke Zara Ba...
# 1   6Yb13Od1beXcshjO6vSskt  Zara Hatke Zara Bachke (Original Motion Pictur...
# 2   3LyafXRRJVEfcjTMr1N8Mu                                           Obsessed
# 3   5AivaZj0CiQJoDWqVH2pbh                                       Still Rollin
# 4   15CyNDuGY5fsG0Hn9rjnpG                                     Champagne Talk
# 5   7kXEDaT5yy8IUT7Fmqs1i2       O Bedardeya (From "Tu Jhoothi Main Makkaar")
# 6   7khRLZe8P6XcUoRgOa3nnf                                       Malang Sajna
# 7   4kIPlpwEZBK9JaI9pZHe79    Brahmastra (Original Motion Picture Soundtrack)
# 8   54ubCIO3voLnU7ZmJhxqBd                                    Zihaal e Miskin
# 9   6BHlJhCk1vjCG6hqTG2SFV                                    Kahani Suno 2.0
# 10  25OmZbss1JS6CdFqFDiaNu                    Ram Siya Ram (From "Adipurush")
# 11  5Wm1nhxZqx7i0Hp6ZBqe9T                     Love Forever With Arijit Singh
# 12  5AivaZj0CiQJoDWqVH2pbh                                       Still Rollin
# 13  5uAi4ZZc7zRdd6PsKNcJXO   Tere Pyaar Mein (From "Tu Jhoothi Main Makkaar")
# 14  1lZk7TnMgvS3mSlfeWW1b3           Tere Hawaale (From "Laal Singh Chaddha")
# 15  5Zcgog7sQ79ISF32y9nABU                                            No Love
# 16  76spwPLkGkvPtADGCTkNeT                                       Kya Loge Tum
# 17  3RaIXDlIRvziryGLXm8lBR                                               Daku
# 18  2ooWY7xriwwyj23dAI32C2                                            Pathaan
# 19  7uftfPn8f7lwtRLUrEVRYM                                       The Carnival
# 20  6AJaDEafyyyWWXHZQtcFGe                                    Chaand Baaliyan
# 21  44aCFqUbG06fL58kqpMp8p                                             Baller
# 22  1cttjZoENYipDCPgISthpY  Pyaar Hota Kayi Baar Hai (From "Tu Jhoothi Mai...
# 23  4qlI6YM61j9NeGe832mExq                                            Forever
# 24  2DKSZvMj7Da6rzNVPMgREj                Raataan Lambiyan (From "Shershaah")
# 25  45ZIondgVoMB84MQQaUo9T                                          Moosetape
# 26  3I8PdIhk6pNm8Kv0HiF14V       Tujhe Kitna Chahne Lage (From "Kabir Singh")
# 27  6KgPhunJItRDOhJFh6Sy78                                         Drive Thru
# 28  3fOswFPlmSWKTTFTlksdiv                                        HIDDEN GEMS
# 29  0azGrKHPYvl2MEKwQFfbV2                                            Mi Amor
# 30  6u5RdRVp5HBStyPRWvHcgm                                               Thaa
# 31  3GkXRRRkV3rfgwG1wJset9                                            Excuses
# 32  2GPHbR6aZ2rZooX6dF1nwB                                              VIBIN
# 33  5CvI5ppsG522pV554VLezD                     Besharam Rang (From "Pathaan")
# 34  4ysOhipyMXKstywus51VXS                                         Baarishein
# 35  4QCM8VlhhlwZtQ2Ew7gtIg                                                Pal
# 36  0Z1zYMwJRpvq0d9rdqTOYo                          Ranjha (From "Shershaah")
# 37  1N9rGbn2M9lzU6YcJ6081E                                             Manjha
# 38  6IXfWhC7omotM4lt0ROmEr  Love Aaj Kal (Original Motion Picture Soundtrack)
# 39  5letLUZIFsQikJYShfGNs4                               The Beginning: Cupid
# 40  7Gws1vUsWltRs58x8QuYVQ  Table No. 21 (Original Motion Picture Soundtrack)
# 41  5hzAIEMlQpsEGIQFvnFOQx                       Duniyaa (From "Luka Chuppi")
# 42  1ncyKqyZae6DoyjYaV9LmS                     Kaise Hua (From "Kabir Singh")
# 43  5Hmh6N8oisrcuZKa8EY5dn                                             People
# 44  2HZl13JCi3PIaqVlIkp4q6  Shor in the City (Original Motion Picture Soun...
# 45  3jeQDa9OFZ6GndLindHx3k                                           Take Two
# 46  64MZHXV7IglO8LE8KplSRw                                             ANYWAY
# 47  4kIPlpwEZBK9JaI9pZHe79    Brahmastra (Original Motion Picture Soundtrack)
# 48  2ODvWsOgouMbaA5xf0RkJe                                            Starboy
# 49  1WwkojG9sjMSrFVz4D51W0                 Ultimate Love Songs - Arijit Singh
#
#    release_date  total_tracks  \
# 0    2023-05-16             1
# 1    2023-05-30             4
# 2    2022-09-29             1
# 3    2023-05-19             7
# 4    2022-10-12             8
# 5    2023-03-04             1
# 6    2022-12-19             1
# 7    2022-10-06             9
# 8    2023-05-25             1
# 9    2022-05-31             1
# 10   2023-05-29             1
# 11   2017-06-07            20
# 12   2023-05-19             7
# 13   2023-02-01             1
# 14   2022-08-04             1
# 15   2022-02-22             1
# 16   2023-05-15             1
# 17   2021-01-16             1
# 18   2022-12-22             4
# 19   2020-09-21             8
# 20   2020-03-28             1
# 21   2022-09-09             1
# 22   2023-02-10             1
# 23   2022-11-16             6
# 24   2021-07-30             1
# 25   2021-05-15            32
# 26   2019-05-31             1
# 27   2022-07-15             5
# 28   2021-11-21             6
# 29   2022-09-30             1
# 30   2023-03-25             1
# 31   2020-07-24             1
# 32   2023-01-09             7
# 33   2022-12-12             1
# 34   2018-01-12             1
# 35   2018-09-14             1
# 36   2021-08-05             1
# 37   2020-03-17             1
# 38   2020-02-14            11
# 39   2023-02-24             3
# 40   2012-12-21             5
# 41   2019-02-22             1
# 42   2019-06-13             1
# 43   2022-12-06             1
# 44   2011-03-28             8
# 45   2023-06-09             1
# 46   2023-01-30            10
# 47   2022-10-06             9
# 48   2016-11-25            18
# 49   2020-05-19            10
#
#                                                   url
# 0   https://open.spotify.com/album/1skD49xUwXnHLMr...
# 1   https://open.spotify.com/album/6Yb13Od1beXcshj...
# 2   https://open.spotify.com/album/3LyafXRRJVEfcjT...
# 3   https://open.spotify.com/album/5AivaZj0CiQJoDW...
# 4   https://open.spotify.com/album/15CyNDuGY5fsG0H...
# 5   https://open.spotify.com/album/7kXEDaT5yy8IUT7...
# 6   https://open.spotify.com/album/7khRLZe8P6XcUoR...
# 7   https://open.spotify.com/album/4kIPlpwEZBK9JaI...
# 8   https://open.spotify.com/album/54ubCIO3voLnU7Z...
# 9   https://open.spotify.com/album/6BHlJhCk1vjCG6h...
# 10  https://open.spotify.com/album/25OmZbss1JS6CdF...
# 11  https://open.spotify.com/album/5Wm1nhxZqx7i0Hp...
# 12  https://open.spotify.com/album/5AivaZj0CiQJoDW...
# 13  https://open.spotify.com/album/5uAi4ZZc7zRdd6P...
# 14  https://open.spotify.com/album/1lZk7TnMgvS3mSl...
# 15  https://open.spotify.com/album/5Zcgog7sQ79ISF3...
# 16  https://open.spotify.com/album/76spwPLkGkvPtAD...
# 17  https://open.spotify.com/album/3RaIXDlIRvziryG...
# 18  https://open.spotify.com/album/2ooWY7xriwwyj23...
# 19  https://open.spotify.com/album/7uftfPn8f7lwtRL...
# 20  https://open.spotify.com/album/6AJaDEafyyyWWXH...
# 21  https://open.spotify.com/album/44aCFqUbG06fL58...
# 22  https://open.spotify.com/album/1cttjZoENYipDCP...
# 23  https://open.spotify.com/album/4qlI6YM61j9NeGe...
# 24  https://open.spotify.com/album/2DKSZvMj7Da6rzN...
# 25  https://open.spotify.com/album/45ZIondgVoMB84M...
# 26  https://open.spotify.com/album/3I8PdIhk6pNm8Kv...
# 27  https://open.spotify.com/album/6KgPhunJItRDOhJ...
# 28  https://open.spotify.com/album/3fOswFPlmSWKTTF...
# 29  https://open.spotify.com/album/0azGrKHPYvl2MEK...
# 30  https://open.spotify.com/album/6u5RdRVp5HBStyP...
# 31  https://open.spotify.com/album/3GkXRRRkV3rfgwG...
# 32  https://open.spotify.com/album/2GPHbR6aZ2rZooX...
# 33  https://open.spotify.com/album/5CvI5ppsG522pV5...
# 34  https://open.spotify.com/album/4ysOhipyMXKstyw...
# 35  https://open.spotify.com/album/4QCM8VlhhlwZtQ2...
# 36  https://open.spotify.com/album/0Z1zYMwJRpvq0d9...
# 37  https://open.spotify.com/album/1N9rGbn2M9lzU6Y...
# 38  https://open.spotify.com/album/6IXfWhC7omotM4l...
# 39  https://open.spotify.com/album/5letLUZIFsQikJY...
# 40  https://open.spotify.com/album/7Gws1vUsWltRs58...
# 41  https://open.spotify.com/album/5hzAIEMlQpsEGIQ...
# 42  https://open.spotify.com/album/1ncyKqyZae6Doyj...
# 43  https://open.spotify.com/album/5Hmh6N8oisrcuZK...
# 44  https://open.spotify.com/album/2HZl13JCi3PIaqV...
# 45  https://open.spotify.com/album/3jeQDa9OFZ6GndL...
# 46  https://open.spotify.com/album/64MZHXV7IglO8LE...
# 47  https://open.spotify.com/album/4kIPlpwEZBK9JaI...
# 48  https://open.spotify.com/album/2ODvWsOgouMbaA5...
# 49  https://open.spotify.com/album/1WwkojG9sjMSrFV...

# %%
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   album_id      50 non-null     object
#  1   name          50 non-null     object
#  2   release_date  50 non-null     object
#  3   total_tracks  50 non-null     int64
#  4   url           50 non-null     object
# dtypes: int64(1), object(4)
# memory usage: 2.1+ KB

# %%
album_df = album_df.drop_duplicates(subset=['album_id'])

# %%
artist_df = pd.DataFrame.from_dict(artist_list)

# %%
artist_df = artist_df.drop_duplicates(subset=['artist_id'])

# %%
artist_df
# Out:
#                   artist_id            artist_name  \
# 0    1mBydYMVBECdDmMfE2sEUO           Sachin-Jigar
# 1    4YRxDV8wJFPHPTeXepOstw           Arijit Singh
# 2    7uw9rkZ9mxuSBuURy86ERR  Amitabha Bhattacharya
# 3    4gzrZDyL5gYiROkv27pYKx             Varun Jain
# 5    6WixbETKEXH0xBf0OB9kRB          Shadab Faridi
# ..                      ...                    ...
# 110  0uOUeC51AxGnP6hB8gurwt               Cheema Y
# 111  0QntOArZgiNHoemAzwJPu5              Gur Sidhu
# 115  00sCATpEvwH48ays7PlQFU          Jonita Gandhi
# 116  1Xyo4u8uXC1ZmMpatF05PJ             The Weeknd
# 117  4tZwfgrHOc3mvqYlEYSvVi              Daft Punk
#
#                                           external_url
# 0    https://api.spotify.com/v1/artists/1mBydYMVBEC...
# 1    https://api.spotify.com/v1/artists/4YRxDV8wJFP...
# 2    https://api.spotify.com/v1/artists/7uw9rkZ9mxu...
# 3    https://api.spotify.com/v1/artists/4gzrZDyL5gY...
# 5    https://api.spotify.com/v1/artists/6WixbETKEXH...
# ..                                                 ...
# 110  https://api.spotify.com/v1/artists/0uOUeC51AxG...
# 111  https://api.spotify.com/v1/artists/0QntOArZgiN...
# 115  https://api.spotify.com/v1/artists/00sCATpEvwH...
# 116  https://api.spotify.com/v1/artists/1Xyo4u8uXC1...
# 117  https://api.spotify.com/v1/artists/4tZwfgrHOc3...
#
# [72 rows x 3 columns]

# %%
#Song Dataframe
song_df = pd.DataFrame.from_dict(song_list)

# %%
song_df.head()
# Out:
#                   song_id                                          song_name  \
# 0  7Ky9U9iHjGBiRax3joCRDS  Phir Aur Kya Chahiye (From "Zara Hatke Zara Ba...
# 1  5GhNEr3AQtMhHGYLRgCSV5                                        Tere Vaaste
# 2  6Z4rRhYZVQsYKmrxD40tru                                           Obsessed
# 3  6oz1L5jcqZWYuId7nxvIan                                       Still Rollin
# 4  1418IuVKQPTYqt7QNJ9RXN                                     Maan Meri Jaan
#
#    duration_ms                                                url  popularity  \
# 0       266075  https://open.spotify.com/track/7Ky9U9iHjGBiRax...          66
# 1       189136  https://open.spotify.com/track/5GhNEr3AQtMhHGY...          56
# 2       190444  https://open.spotify.com/track/6Z4rRhYZVQsYKmr...          84
# 3       174730  https://open.spotify.com/track/6oz1L5jcqZWYuId...          81
# 4       194653  https://open.spotify.com/track/1418IuVKQPTYqt7...          86
#
#              song_added                album_id               artist_id
# 0  2023-06-12T09:44:12Z  1skD49xUwXnHLMrlEKTo6j  1mBydYMVBECdDmMfE2sEUO
# 1  2023-06-12T09:44:12Z  6Yb13Od1beXcshjO6vSskt  1mBydYMVBECdDmMfE2sEUO
# 2  2023-06-12T09:44:12Z  3LyafXRRJVEfcjTMr1N8Mu  34gAaWeYZoRER7MY3KBy1Q
# 3  2023-06-12T09:44:12Z  5AivaZj0CiQJoDWqVH2pbh  5r3wPya2PpeTTsXsGhQU8O
# 4  2023-06-12T09:44:12Z  15CyNDuGY5fsG0Hn9rjnpG  5NHm4TU5Twz7owibYxJfFU

# %%
album_df['release_date'] = pd.to_datetime(album_df['release_date'])
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_7024\3126744046.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   album_df['release_date'] = pd.to_datetime(album_df['release_date'])

# %%
song_df['song_added'] =  pd.to_datetime(song_df['song_added'])

# %%
song_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   song_id      50 non-null     object
#  1   song_name    50 non-null     object
#  2   duration_ms  50 non-null     int64
#  3   url          50 non-null     object
#  4   popularity   50 non-null     int64
#  5   song_added   50 non-null     datetime64[ns, UTC]
#  6   album_id     50 non-null     object
#  7   artist_id    50 non-null     object
# dtypes: datetime64[ns, UTC](1), int64(2), object(5)
# memory usage: 3.2+ KB

# %%
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 48 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   album_id      48 non-null     object
#  1   name          48 non-null     object
#  2   release_date  48 non-null     datetime64[ns]
#  3   total_tracks  48 non-null     int64
#  4   url           48 non-null     object
# dtypes: datetime64[ns](1), int64(1), object(3)
# memory usage: 2.2+ KB
